# %%
# %pip install -Uq \
# langchain langchain-community langchain-huggingface langchain-chroma \
# pypdf transformers accelerate Xformers InstructorEmbedding \
# sentencepiece bitsandbytes tiktoken chromadb typer semantic_split \
# cryptography

# REMEMBER TO INSTALL TORCH WITH CUDA

# %% [markdown]
# # Document Pre-Processing
#
# Document pre-processing is split into two parts:
# - Clean trailing/extra spaces
# - Splitting text into smaller chunks

# %%
import os

from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader

# %%
path = "../assets/ncvs_documents/"
loader = DirectoryLoader(path=path,
                         glob="*.pdf",
                         loader_cls=PyPDFLoader)
documents = loader.load()
len(documents)
# Out:
# 626

# %% [markdown]
# ## Clean trailing or extra whitespaces.

# %%
import re

for i in range(len(documents)):
  cleaned_docs = re.sub("\s+", " ", documents[i].page_content)    # remove trailing spaces
  documents[i].page_content = cleaned_docs

# %% [markdown]
# ## Splitting into Chunks
#
# We split the text into smaller chunks. For this experiment, we will stick to 512 `chunk_size` and 250 `chunk_overlap` to persist context between retrievals.
# This is also because we have to take into account the embedding model's maximum sequence length.

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=512,
                                          chunk_overlap=250,
                                          separators=["\n\n",
                                                      "\n",
                                                      " ",
                                                      ".",
                                                      ",",
                                                      "\u200b",  # Zero-width space
                                                      "\uff0c",  # Fullwidth comma
                                                      "\u3001",  # Ideographic comma
                                                      "\uff0e",  # Fullwidth full stop
                                                      "\u3002",  # Ideographic full stop
                                                      ""])

# %%
text = splitter.split_documents(documents)
print(f"Recursive: {len(text)}")
# Out:
# Recursive: 10410

# %% [markdown]
# # ChromaDB Collections
#
# Text chunks processed will be passed through an embedding model and saved into
# a ChromaDB database (collection).

# %% [markdown]
# we define a custom embedding function to use for embedding the texts before storing it into the database.

# %%
import os
import chromadb
from chromadb import Documents, EmbeddingFunction, Embeddings
from chromadb.utils.batch_utils import create_batches
from sentence_transformers import SentenceTransformer

dir = "db"
client = chromadb.PersistentClient(path=dir)

class MyEmbeddingFunction(EmbeddingFunction[Documents]):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.model = SentenceTransformer('all-distilroberta-v1', device='cuda')
        # consider using voyage-law-2

    def __call__(self, input: Documents) -> Embeddings:
        # embed the documents
        sentences = input
        embeddings = self.model.encode(sentences)
        return embeddings.tolist()

embedding_function = MyEmbeddingFunction()

# %% [markdown]
# retrieve an existing collection from the database if it exsists. if not, we shall create a new collection
# and populate it with the documents.

# %%
try: 
    collection = client.get_collection(name="ncvs-idn", embedding_function=embedding_function)

except ValueError: 
    collection = client.create_collection(name="ncvs-idn", embedding_function=embedding_function)
    batches = create_batches(api=client, 
                            ids=["NCVS{n:03}".format(n=i) for i in range(1, len(text)+1)],
                            documents=[s.page_content for s in text], 
                            metadatas=[s.metadata for s in text])

    for batch in batches: 
        collection.upsert(
            ids=batch[0], 
            documents=batch[3], 
            metadatas=batch[2])

# %% [markdown]
# # Generation Model
#
# In theory, we could use any generative models. But since there are hardware constraints, we opted to use OpenAI's models.

# %%
from openai import OpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import RetrievalQA
from pprint import pprint

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PROMPT_TEMPLATE = """
Use the following context (delimited by <ctx></ctx>), \
chat history (delimited by <hs></hs>) and source \
(delimted by <src></src>) to answer the question:
---------------------
{context}
---------------------
{history}
---------------------
{source}
---------------------
Question: {query}
"""
k=7

# %% [markdown]
# define a function to format the retrieved documents from the database

# %%
def generate_prompt_items(query: str): 
    retrieve = collection.query(
        query_texts=[query], 
        n_results=k
    )

    context = [["<ctx>" + s + "</ctx>" for s in chunk] for chunk in retrieve.get("documents")]
    context = "".join("\n\n".join(chunk) for chunk in context)

    source = [["<src>" + "Source: " + s["source"] + ", page: " + str(s["page"]) + "</src>" for s in chunk] for chunk in retrieve.get("metadatas")]
    source  = "".join("\n\n".join(chunk) for chunk in source)
    return context, source

# %% [markdown]
# define a function to abstract the process of generating a response from the OpenAI model.

# %%
def generate_openai_response(query): 
    context, source = generate_prompt_items(query)
    client = OpenAI(api_key=OPENAI_API_KEY)

    return client.chat.completions.create(
        model="gpt-3.5-turbo", 
        messages = [
            {
                "role":"system", 
                "content": "You will be provided a context (delimited by <ctx></ctx>) and the context source \
                            (delimited by <src></src>). Answer the question only based on the context given. \
                            Include the sources used in the answer you generated after the final paragraph, \
                            formatted with bullets for each different sources and sort it in a ascending manner."
            },
            {
                "role": "assistant",
                "content": context
            },
            {
                "role": "assistant",
                "content": source
            },
            {
                "role": "user",
                "content": query
            }
        ],
        temperature=0
    ).choices[0].message.content

# %% [markdown]
# # Evaluating the retrievals

# %% [markdown]
# ## Generate a dataset for evaluating the answer given
#
# To evaluate the retrieval quality, we will use `hitrate@k`, `precision@k`, `recall@k`, and mean reciprocal rank (MRR). Creating
# a custom dataset for example queries and expected answer source will be sufficient for this purpose.

# %%
import pandas as pd
data = {
    'Question': [
        'What is Gross Tonnage and how do I calculate it?', 
        'Can you explain to me what are the differences of each life jacket categories?', 
        'How can I determine if my crew count is sufficient?', 
        'What kinds of certificates are stated in the NCVS Book?', 
        'Explain to me more about vessel operational area', 
        'Bottom shell plating and how to calculate them', 
        'List the requirements for radio equipments on a vessel', 
        'How does one construct and evaluate a MES?', 
        'Does a life raft have categories? If so how much?', 
    ], 
    'Answer': [
        ['chapter-7'], 
        ['chapter-4'], 
        ['chapter-8'], 
        ['chapter-9'], 
        ['chapter-1'], 
        ['chapter-2'],
        ['chapter-3'],
        ['chapter-4'],
        ['chapter-4']
    ]
}
df = pd.DataFrame(data)

queries = df['Question']
targets = df['Answer']

# %% [markdown]
# ## Define function to calculate `hitrate@k`

# %%
def hitrate_at_k(query, source_targets): 
    retrieval_results = collection.query(
        query_texts=[query], 
        n_results=k)
    
    source = [["<src>" + "Source: " + s["source"] + ", page: " + str(s["page"]) + "</src>" for s in chunk] for chunk in retrieval_results.get("metadatas")]

    count = 0
    for target in source_targets: 
        for retrieved in source[0]: 
            if target in retrieved.lower(): 
                count += 1
                continue
    
    return count/k

# %% [markdown]
# ## Define function to calculate `recall@k`

# %%
def recall_at_k(query, source_targets): 
    retrieval_results = collection.query(
        query_texts=[query], 
        n_results=k)
    
    source = [["<src>" + "Source: " + s["source"] + ", page: " + str(s["page"]) + "</src>" for s in chunk] for chunk in retrieval_results.get("metadatas")]

    count = 0
    for target in source_targets: 
        for retrieved in source[0]: 
            if target in retrieved.lower(): 
                count += 1
                break
    
    return count/len(source_targets)

# %% [markdown]
# ## Define function to calculate `precision@k`

# %%
def precision_at_k(query, source_targets): 
    retrieval_results = collection.query(
        query_texts=[query], 
        n_results=k)
    
    source = [["<src>" + "Source: " + s["source"] + ", page: " + str(s["page"]) + "</src>" for s in chunk] for chunk in retrieval_results.get("metadatas")]

    count = 0
    for target in source_targets: 
        for retrieved in source[0]: 
            if target in retrieved.lower(): 
                count += 1
                continue
    
    return count/len(source[0])

# %% [markdown]
# ## Define function to calculate mean reciprocal ranks

# %%
def mean_reciprocal_rank(query, source_targets): 
    retrieval_results = collection.query(
        query_texts=[query], 
        n_results=k)
    
    source = [["<src>" + "Source: " + s["source"] + ", page: " + str(s["page"]) + "</src>" for s in chunk] for chunk in retrieval_results.get("metadatas")]

    reciprocal_ranks = [1/(i+1) for target in source_targets for i, result in enumerate(source[0]) if target in result.lower()]
    try: 
        return sum(reciprocal_ranks)/len(reciprocal_ranks)
    except ZeroDivisionError: 
        return 0

# %% [markdown]
# ## Calculate average of each metrics

# %%
hit = []
pre = [] 
rec = []
mrr = []

for i, (q, a)in enumerate(zip(queries, targets)): 
    hit.append(hitrate_at_k(q, a))
    pre.append(precision_at_k(q, a))
    rec.append(recall_at_k(q, a))
    mrr.append(mean_reciprocal_rank(q, a))

print(f"Average hitrate over {k} queries: {sum(hit)/len(hit)}")
print(f"Average precision over {k} queries: {sum(pre)/len(pre)}")
print(f"Average recall over {k} queries: {sum(rec)/len(rec)}")
print(f"Average mean reciprocal ranks over {k} queries: {sum(mrr)/len(mrr)}")
# Out:
# Average hitrate over 7 queries: 0.8095238095238095
# Average precision over 7 queries: 0.8095238095238095
# Average recall over 7 queries: 0.8888888888888888
# Average mean reciprocal ranks over 7 queries: 0.32507243638196015

# %% [markdown]
# # Testing the output

# %%
for q, ans in zip(queries, targets): 
    print("\n===================================\n")
    print("Question: {}\n\nAnswer: {}".format(q, 
                                           generate_openai_response(q)))
# Out:
# ===================================
#
# Question: What is Gross Tonnage and how do I calculate it?
#
# Answer: Gross Tonnage (GT) is the total volume of a ship's enclosed spaces, both below and above the deck. To calculate Gross Tonnage, you can use the following formula: GT = 0.25 x (V), where V is the total volume of enclosed spaces under the deck (V1) plus the volume of enclosed spaces above the deck (V2). The cubic volume of the spaces under the deck (V1) can be determined using measurements from the vessel's Lines Plan or by multiplying the Length (L), Width (W), and Depth (D). The function of rooms on the vessel is no longer considered in the calculation of Gross Tonnage.
#
# Sources:
# - CHAPTER-7-TONNAGE_MEASUREMENT_V.4.4_1708919257504_0.pdf (page 3)
#
# ===================================
#
# Question: Can you explain to me what are the differences of each life jacket categories?
#
# Answer: The different categories of life jackets have specific requirements and purposes:
#
# 1. Category A Life Jacket:
#    - Must not burn or melt after being engulfed by fire in 2 seconds.
#    - Designed for adults, ensuring at least 75% of users unfamiliar with wearing life jackets can wear it.
#
# 2. Category B Life Jacket:
#    - Must comply with minimum requirements before design approval.
#    - Includes a light and whistle attached to the life jacket.
#
# 3. Category C Life Jacket:
#    - For use as defined by the Authority for all body weight ranges.
#    - Must be clearly marked 'LIFE JACKET' in indelible lettering not less than 25 mm high.
#
# Each category is tailored to specific needs and situations, ensuring safety and compliance with regulations based on the intended use and user requirements.
#
# Sources:
# - CHAPTER-4_LIFE_SAVING_APPLIANCES_v.4.4_1708919237619_0.pdf, page: 25
# - CHAPTER-4_LIFE_SAVING_APPLIANCES_v.4.4_1708919237619_0.pdf, page: 26
# - CHAPTER-4_LIFE_SAVING_APPLIANCES_v.4.4_1708919237619_0.pdf, page: 28
#
# ===================================
#
# Question: How can I determine if my crew count is sufficient?
#
# Answer: To determine if your crew count is sufficient, you should evaluate the following factors:
#
# 1. The specific duties or work of the vessel and any additional crew needed to support navigation safety.
# 2. The total number of people onboard the vessel.
# 3. The design characteristics of the vessel, including its systems and operations.
# 4. The risks to the vessel and persons onboard, such as crew and passengers.
#
# By considering these factors, you can assess whether your current crew count is adequate to ensure the safe operation and navigation of the vessel. It is essential to have a competent and trained crew onboard to handle normal and emergency situations effectively.
#
# Sources:
# - CHAPTER-8_MANNING_v.4.4_1708919279022_0.pdf, page: 11
#
# ===================================
#
# Question: What kinds of certificates are stated in the NCVS Book?
#
# Answer: The NCVS Book mentions various types of certificates such as Certificate of Competence, Certificates of Proficiency, Certificate of Endorsement, and Endorsement Certificate. These certificates may have different validity periods, revalidation requirements, and conditions based on the specific regulations and standards at the time of issuance or renewal.
#
# The certificates mentioned in the NCVS Book are crucial for ensuring compliance with safety management standards and regulations in the maritime industry.
#
# Sources:
# - CHAPTER-6_LOAD_LINES_v.4.4_1708919269763_0.pdf, page: 1
# - CHAPTER-8_MANNING_v.4.4_1708919279022_0.pdf, page: 1
# - CHAPTER-9_MANAGEMENT_OPERATIONAL_v.4.4_1708919289106_0.pdf, page: 1
#
# ===================================
#
# Question: Explain to me more about vessel operational area
#
# Answer: Vessel operational area refers to the geographical limit within which a vessel is authorized to operate based on various factors such as geographical and meteorological conditions, ship's ordinance, and regulations like SOLAS 1929, 1948, 1960, and 1974. The operational area categories are defined to specify the limits of a vessel's area of operations. These categories include:
#
# 1. Unlimited operations: All operations beyond 200 nautical miles from the coast.
# 2. Offshore operations: Operations within a limit of 200 nautical miles from the coast or within lesser limits specified by the Authority.
# 3. Restricted offshore operations: Operations within specific limits determined by the Authority.
# 4. Local operational areas: Areas closer to the coast where vessels operate.
# 5. Limited operational areas: Areas with restricted access for vessels.
# 6. Operational areas of ports and surrounding areas: Areas around ports where vessels operate.
#
# The operational area of a vessel is crucial as it determines the risks associated with its operation, considering factors like weather conditions, wave magnitude, and potential hazards. Vessels must adhere to the designated operational area to ensure safety, prevent accidents, and protect the environment.
#
# Sources:
# - CHAPTER-1_INTRODUCTION_v.4.4_1708919173888_0.pdf (Page 22)
# - CHAPTER-8_MANNING_v.4.4_1708919279022_0.pdf (Page 2)
#
# ===================================
#
# Question: Bottom shell plating and how to calculate them
#
# Answer: Bottom shell plating thickness is determined by specific equations based on the type of framing used in the vessel. For vessels with transversely-framed bottoms, the thickness of the bottom shell plating is calculated using the equation: t = thickness of bottom shell plating in mm. For vessels with longitudinally-framed bottoms, the equation is: t = thickness of bottom shell plating in mm. Additionally, the thickness of the bottom shell plating should not be less than that obtained from the equations provided in the relevant clauses. The calculations involve parameters such as frame spacing, length of the vessel, and distance from the lower edge of the plate to the freeboard deck side.
#
# To calculate the thickness of the side shell plating, the equation is: t = thickness in mm, where parameters like frame spacing and vessel length are considered. The thickness of the inner-bottom plating is determined by the equation: t = 0.037L + 0.009s mm, with adjustments based on specific conditions like the absence of ceiling under cargo hatchways or the vessel's engagement in certain trades.
#
# In summary, the thickness of bottom shell plating, side shell plating, and inner-bottom plating in a vessel is calculated using specific equations that take into account factors such as frame spacing, vessel length, and specific conditions of the vessel's operation.
#
# Sources:
# - CHAPTER-2_CONSTRUCTION_v._4.4_1708919219897_0.pdf, page: 69, 81
#
# ===================================
#
# Question: List the requirements for radio equipments on a vessel
#
# Answer: The requirements for radio equipment on a vessel include:
#
# - Capable of receiving shore to-ship distress alerts
# - Capable of transmitting and receiving ship-to-ship distress alerts
# - Capable of transmitting and receiving search and rescue coordinating communications
# - Capable of transmitting signals for locating the position of an accident
# - Capable of transmitting and receiving maritime safety information
# - Capable of transmitting and receiving general radio communication from shore-based radio systems
# - Capable of transmitting and receiving bridge-to-bridge communication
#
# These requirements ensure that the radio equipment on a vessel is equipped to handle various communication needs and emergencies effectively.
#
# Sources:
# - CHAPTER-3_EQUIPMENT_v.4.4_1708919228097_0.pdf, page: 4
#
# ===================================
#
# Question: How does one construct and evaluate a MES?
#
# Answer: To construct and evaluate a MES (Manual Electric Steering) system, the following steps can be taken:
#
# 1. **Design and Construction**:
#    - Design the MES system based on the requirements and specifications of the steering mechanism.
#    - Construct the MES system by assembling the necessary components such as electric motors, controllers, sensors, and steering mechanisms.
#    - Ensure that the MES system is installed correctly and securely on the steering mechanism of the vessel.
#
# 2. **Testing and Calibration**:
#    - Test the MES system to ensure that it functions correctly and responds accurately to steering inputs.
#    - Calibrate the MES system to adjust sensitivity, response time, and other parameters to optimize its performance.
#    - Conduct sea trials or simulation tests to evaluate the performance of the MES system in different operating conditions.
#
# 3. **Safety and Reliability**:
#    - Ensure that the MES system meets safety standards and regulations for marine steering systems.
#    - Evaluate the reliability of the MES system by conducting reliability tests and analyzing potential failure modes.
#
# 4. **Performance Evaluation**:
#    - Evaluate the performance of the MES system in terms of steering accuracy, responsiveness, power consumption, and overall efficiency.
#    - Compare the performance of the MES system with traditional steering systems to assess its advantages and limitations.
#
# 5. **Feedback and Improvement**:
#    - Gather feedback from operators and users of the MES system to identify areas for improvement.
#    - Implement necessary modifications or upgrades to enhance the performance, reliability, and safety of the MES system.
#
# By following these steps, one can effectively construct and evaluate a MES system for marine vessels.
#
# Sources:
# - CHAPTER-2_CONSTRUCTION_v._4.4_1708919219897_0.pdf
# - CHAPTER-7-TONNAGE_MEASUREMENT_V.4.4_1708919257504_0.pdf
#
# ===================================
#
# Question: Does a life raft have categories? If so how much?
#
# Answer: Yes, a life raft has categories. There are at least three categories mentioned in the provided context:
#
# 1. Category C
# 2. Category D
# 3. Category E
#
# Each category may have specific requirements and characteristics for the type of life raft to be used in different situations or conditions.
