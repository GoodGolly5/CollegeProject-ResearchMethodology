# %%
# %pip install -Uq \
# langchain langchain-community langchain-huggingface langchain-chroma \
# pypdf transformers accelerate Xformers InstructorEmbedding \
# sentencepiece bitsandbytes tiktoken chromadb typer semantic_split \
# cryptography

# %% [markdown]
# # Document Pre-Processing
#
# Document pre-processing is split into two parts:
# - Clean trailing/extra spaces
# - Splitting text into smaller chunks

# %%
import os

from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader

# %%
path = "../assets/ncvs_documents/"
loader = DirectoryLoader(path=path,
                         glob="*.pdf",
                         loader_cls=PyPDFLoader)
documents = loader.load()
len(documents)
# Out:
# 626

# %% [markdown]
# ## Clean trailing or extra whitespaces.

# %%
import re

for i in range(len(documents)):
  cleaned_docs = re.sub("\s\W\s", " ", documents[i].page_content)  # remove weird dashes
  cleaned_docs = re.sub("\s+", " ", cleaned_docs)    # remove trailing spaces
  documents[i].page_content = cleaned_docs

# %% [markdown]
# ## Splitting into Chunks
#
# There are two such splitters that are recommended here, one is the `RecursiveCharacterTextSplitter`from Langchain and the other is the [`semantic-split`](https://github.com/agamm/semantic-split) by Agamm.
#
# > Known issues:
# > `semantic-split` uses string as arguments, meaning we _could_ very well lose page metadata of the content itself. Workaround is in progress.

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000,
                                          chunk_overlap=250,
                                          separators=["\n\n",
                                                      "\n",
                                                      " ",
                                                      ".",
                                                      ",",
                                                      "\u200b",  # Zero-width space
                                                      "\uff0c",  # Fullwidth comma
                                                      "\u3001",  # Ideographic comma
                                                      "\uff0e",  # Fullwidth full stop
                                                      "\u3002",  # Ideographic full stop
                                                      ""])

# %%
text = splitter.split_documents(documents)
print(f"Recursive: {len(text)}")
# Out:
# Recursive: 3954

# %% [markdown]
# # ChromaDB Collections
#
# Text chunks processed will be passed through an embedding model and saved into
# a ChromaDB database (collection).

# %%
from os import walk

mypath = "../assets/ncvs_documents/"
filenames = next(walk(mypath), (None, None, []))[2]  # [] if no file
filenames.sort()
filenames
# Out:
# ['CHAPTER-1_INTRODUCTION_v.4.4_1708919173888_0.pdf',
#  'CHAPTER-2_CONSTRUCTION_v._4.4_1708919219897_0.pdf',
#  'CHAPTER-3_EQUIPMENT_v.4.4_1708919228097_0.pdf',
#  'CHAPTER-4_LIFE_SAVING_APPLIANCES_v.4.4_1708919237619_0.pdf',
#  'CHAPTER-5_MACHINERY_AND_ELECTRICAL_v.4.4_1708919243730_0.pdf',
#  'CHAPTER-6_LOAD_LINES_v.4.4_1708919269763_0.pdf',
#  'CHAPTER-7-TONNAGE_MEASUREMENT_V.4.4_1708919257504_0.pdf',
#  'CHAPTER-8_MANNING_v.4.4_1708919279022_0.pdf',
#  'CHAPTER-9_MANAGEMENT_OPERATIONAL_v.4.4_1708919289106_0.pdf',
#  'SK_Dirjen_Hubla_No._UM.008-9-20-DJPL_-_2012_1708919307382_0.pdf']

# %%
import os
import chromadb
from chromadb.utils import embedding_functions
from chromadb import Documents, EmbeddingFunction, Embeddings
from sentence_transformers import SentenceTransformer

dir = "db"
client = chromadb.PersistentClient(path=dir)

class MyEmbeddingFunction(EmbeddingFunction[Documents]):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.model = SentenceTransformer('BAAI/bge-m3', device='cuda')
        # consider using voyage-law-2

    def __call__(self, input: Documents) -> Embeddings:
        # embed the documents
        sentences = input
        embeddings = self.model.encode(sentences)
        return embeddings.tolist()

embedding_function = MyEmbeddingFunction()

collection = client.get_or_create_collection(name="ncvs-indonesia",
                                            embedding_function=embedding_function)

# %%
# If something went wrong, remove the collections
# client.delete_collection(name="ncvs-indonesia")

# %% [markdown]
# ## Batching and Inserting
#
# Create batches for the chunks and upsert into database (add if nonexistent or update if exists)

# %%
from chromadb.utils.batch_utils import create_batches
batches = create_batches(api=client, 
                         ids=["NCVS{n:04}".format(n=i) for i in range(1, len(text)+1)],
                         documents=[s.page_content for s in text], 
                         metadatas=[s.metadata for s in text])

for batch in batches: 
    collection.upsert(
        ids=batch[0], 
        documents=batch[3], 
        metadatas=batch[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 from chromadb.utils.batch_utils import create_batches
#       2 batches = create_batches(api=client,
# ----> 3                          ids=["NCVS{n:04}".format(n=i) for i in range(1, len(text)+1)],
#       4                          documents=[s.page_content for s in text],
#       5                          metadatas=[s.metadata for s in text])
#       7 for batch in batches:
#       8     collection.upsert(
#       9         ids=batch[0],
#      10         documents=batch[3],
#      11         metadatas=batch[2])
#
# NameError: name 'text' is not defined

# %% [markdown]
# # Generation Model

# %%
from openai import OpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import RetrievalQA

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PROMPT_TEMPLATE = """
Use the following context (delimited by <ctx></ctx>), \
chat history (delimited by <hs></hs>) and source \
(delimted by <src></src>) to answer the question:
---------------------
{context}
---------------------
{history}
---------------------
{source}
---------------------
Question: {query}
"""

# %%
def generate_prompt_items(query: str): 
    retrieve = collection.query(
        query_texts=[query], 
        n_results=5
    )

    context = [["<ctx>" + s + "</ctx>" for s in chunk] for chunk in retrieve.get("documents")]
    context = "".join("\n\n".join(chunk) for chunk in context)

    source = [["<src>" + "Source: " + s["source"] + ", page: " + str(s["page"]) + "</src>" for s in chunk] for chunk in retrieve.get("metadatas")]
    source  = "".join("\n\n".join(chunk) for chunk in source)
    return context, source

# %%
def generate_openai_response(query): 
    context, source = generate_prompt_items(query)
    client = OpenAI(api_key=OPENAI_API_KEY)

    return client.chat.completions.create(
        model="gpt-3.5-turbo", 
        messages = [
            {
                "role":"system", 
                "content": "You will be provided a context (delimited by <ctx></ctx>) and the context source \
                            (delimited by <src></src>). Answer the question only based on the context given. \
                            Include the sources used in the answer you generated after the final paragraph, \
                            formatted with bullets for each different sources and sort it in a ascending manner."
            },
            {
                "role": "assistant",
                "content": context
            },
            {
                "role": "assistant",
                "content": source
            },
            {
                "role": "user",
                "content": query
            }
        ],
        temperature=0
    ).choices[0].message.content

# %%
question = "How many categories does a lifeboat have?"
print("Question: {}\n\nAnswer: {}".format(question, 
                                           generate_openai_response(question)))
# Out:
# Add of existing embedding ID: NCVS0001
# Add of existing embedding ID: NCVS0002
# Add of existing embedding ID: NCVS0003
# Add of existing embedding ID: NCVS0004
# Add of existing embedding ID: NCVS0005
# Add of existing embedding ID: NCVS0006
# Add of existing embedding ID: NCVS0007
# Add of existing embedding ID: NCVS0008
# Add of existing embedding ID: NCVS0009
# Add of existing embedding ID: NCVS0010
# Add of existing embedding ID: NCVS0011
# Add of existing embedding ID: NCVS0012
# Add of existing embedding ID: NCVS0013
# Add of existing embedding ID: NCVS0014
# Add of existing embedding ID: NCVS0015
# Add of existing embedding ID: NCVS0016
# Add of existing embedding ID: NCVS0017
# Add of existing embedding ID: NCVS0018
# Add of existing embedding ID: NCVS0019
# Add of existing embedding ID: NCVS0020
# Add of existing embedding ID: NCVS0021
# Add of existing embedding ID: NCVS0022
# Add of existing embedding ID: NCVS0023
# Add of existing embedding ID: NCVS0024
# Add of existing embedding ID: NCVS0025
# Add of existing embedding ID: NCVS0026
# Add of existing embedding ID: NCVS0027
# Add of existing embedding ID: NCVS0028
# Add of existing embedding ID: NCVS0029
# Add of existing embedding ID: NCVS0030
# Add of existing embedding ID: NCVS0031
# Add of existing embedding ID: NCVS0032
# Add of existing embedding ID: NCVS0033
# Add of existing embedding ID: NCVS0034
# Add of existing embedding ID: NCVS0035
# Add of existing embedding ID: NCVS0036
# Add of existing embedding ID: NCVS0037
# Add of existing embedding ID: NCVS0038
# Add of existing embedding ID: NCVS0039
# Add of existing embedding ID: NCVS0040
# Add of existing embedding ID: NCVS0041
# Add of existing embedding ID: NCVS0042
# Add of existing embedding ID: NCVS0043
# Add of existing embedding ID: NCVS0044
# Add of existing embedding ID: NCVS0045
# Add of existing embedding ID: NCVS0046
# Add of existing embedding ID: NCVS0047
# Add of existing embedding ID: NCVS0048
# Add of existing embedding ID: NCVS0049
# Add of existing embedding ID: NCVS0050
# Add of existing embedding ID: NCVS0051
# Add of existing embedding ID: NCVS0052
# Add of existing embedding ID: NCVS0053
# Add of existing embedding ID: NCVS0054
# Add of existing embedding ID: NCVS0055
# Add of existing embedding ID: NCVS0056
# Add of existing embedding ID: NCVS0057
# Add of existing embedding ID: NCVS0058
# Add of existing embedding ID: NCVS0059
# Add of existing embedding ID: NCVS0060
# Add of existing embedding ID: NCVS0061
# Add of existing embedding ID: NCVS0062
# Add of existing embedding ID: NCVS0063
# Add of existing embedding ID: NCVS0064
# Add of existing embedding ID: NCVS0065
# Add of existing embedding ID: NCVS0066
# Add of existing embedding ID: NCVS0067
# Add of existing embedding ID: NCVS0068
# Add of existing embedding ID: NCVS0069
# Add of existing embedding ID: NCVS0070
# Add of existing embedding ID: NCVS0071
# Add of existing embedding ID: NCVS0072
# Add of existing embedding ID: NCVS0073
# Add of existing embedding ID: NCVS0074
# Add of existing embedding ID: NCVS0075
# Add of existing embedding ID: NCVS0076
# Add of existing embedding ID: NCVS0077
# Add of existing embedding ID: NCVS0078
# Add of existing embedding ID: NCVS0079
# Add of existing embedding ID: NCVS0080
# Add of existing embedding ID: NCVS0081
# Add of existing embedding ID: NCVS0082
# Add of existing embedding ID: NCVS0083
# Add of existing embedding ID: NCVS0084
# Add of existing embedding ID: NCVS0085
# Add of existing embedding ID: NCVS0086
# Add of existing embedding ID: NCVS0087
# Add of existing embedding ID: NCVS0088
# Add of existing embedding ID: NCVS0089
# Add of existing embedding ID: NCVS0090
# Add of existing embedding ID: NCVS0091
# Add of existing embedding ID: NCVS0092
# Add of existing embedding ID: NCVS0093
# Add of existing embedding ID: NCVS0094
# Add of existing embedding ID: NCVS0095
# Add of existing embedding ID: NCVS0096
# Add of existing embedding ID: NCVS0097
# Add of existing embedding ID: NCVS0098
# Add of existing embedding ID: NCVS0099
# Add of existing embedding ID: NCVS0100
# Add of existing embedding ID: NCVS0101
# Add of existing embedding ID: NCVS0102
# Add of existing embedding ID: NCVS0103
# Add of existing embedding ID: NCVS0104
# Add of existing embedding ID: NCVS0105
# Add of existing embedding ID: NCVS0106
# Add of existing embedding ID: NCVS0107
# Add of existing embedding ID: NCVS0108
# Add of existing embedding ID: NCVS0109
# Add of existing embedding ID: NCVS0110
# Add of existing embedding ID: NCVS0111
# Add of existing embedding ID: NCVS0112
# Add of existing embedding ID: NCVS0113
# Add of existing embedding ID: NCVS0114
# Add of existing embedding ID: NCVS0115
# Add of existing embedding ID: NCVS0116
# Add of existing embedding ID: NCVS0117
# Add of existing embedding ID: NCVS0118
# Add of existing embedding ID: NCVS0119
# Add of existing embedding ID: NCVS0120
# Add of existing embedding ID: NCVS0121
# Add of existing embedding ID: NCVS0122
# Add of existing embedding ID: NCVS0123
# Add of existing embedding ID: NCVS0124
# Add of existing embedding ID: NCVS0125
# Add of existing embedding ID: NCVS0126
# Add of existing embedding ID: NCVS0127
# Add of existing embedding ID: NCVS0128
# Add of existing embedding ID: NCVS0129
# Add of existing embedding ID: NCVS0130
# Add of existing embedding ID: NCVS0131
# Add of existing embedding ID: NCVS0132
# Add of existing embedding ID: NCVS0133
# Add of existing embedding ID: NCVS0134
# Add of existing embedding ID: NCVS0135
# Add of existing embedding ID: NCVS0136
# Add of existing embedding ID: NCVS0137
# Add of existing embedding ID: NCVS0138
# Add of existing embedding ID: NCVS0139
# Add of existing embedding ID: NCVS0140
# Add of existing embedding ID: NCVS0141
# Add of existing embedding ID: NCVS0142
# Add of existing embedding ID: NCVS0143
# Add of existing embedding ID: NCVS0144
# Add of existing embedding ID: NCVS0145
# Add of existing embedding ID: NCVS0146
# Add of existing embedding ID: NCVS0147
# Add of existing embedding ID: NCVS0148
# Add of existing embedding ID: NCVS0149
# Add of existing embedding ID: NCVS0150
# Add of existing embedding ID: NCVS0151
# Add of existing embedding ID: NCVS0152
# Add of existing embedding ID: NCVS0153
# Add of existing embedding ID: NCVS0154
# Add of existing embedding ID: NCVS0155
# Add of existing embedding ID: NCVS0156
# Add of existing embedding ID: NCVS0157
# Add of existing embedding ID: NCVS0158
# Add of existing embedding ID: NCVS0159
# Add of existing embedding ID: NCVS0160
# Add of existing embedding ID: NCVS0161
# Add of existing embedding ID: NCVS0162
# Add of existing embedding ID: NCVS0163
# Add of existing embedding ID: NCVS0164
# Add of existing embedding ID: NCVS0165
# Add of existing embedding ID: NCVS0166
# Add of existing embedding ID: NCVS0167
# Add of existing embedding ID: NCVS0168
# Add of existing embedding ID: NCVS0169
# Add of existing embedding ID: NCVS0170
# Add of existing embedding ID: NCVS0171
# Add of existing embedding ID: NCVS0172
# Add of existing embedding ID: NCVS0173
# Add of existing embedding ID: NCVS0174
# Add of existing embedding ID: NCVS0175
# Add of existing embedding ID: NCVS0176
# Add of existing embedding ID: NCVS0177
# Add of existing embedding ID: NCVS0178
# Add of existing embedding ID: NCVS0179
# Add of existing embedding ID: NCVS0180
# Add of existing embedding ID: NCVS0181
# Add of existing embedding ID: NCVS0182
# Add of existing embedding ID: NCVS0183
# Add of existing embedding ID: NCVS0184
# Add of existing embedding ID: NCVS0185
# Add of existing embedding ID: NCVS0186
# Add of existing embedding ID: NCVS0187
# Add of existing embedding ID: NCVS0188
# Add of existing embedding ID: NCVS0189
# Add of existing embedding ID: NCVS0190
# Add of existing embedding ID: NCVS0191
# Add of existing embedding ID: NCVS0192
# Add of existing embedding ID: NCVS0193
# Add of existing embedding ID: NCVS0194
# Add of existing embedding ID: NCVS0195
# Add of existing embedding ID: NCVS0196
# Add of existing embedding ID: NCVS0197
# Add of existing embedding ID: NCVS0198
# Add of existing embedding ID: NCVS0199
# Add of existing embedding ID: NCVS0200
# Add of existing embedding ID: NCVS0201
# Add of existing embedding ID: NCVS0202
# Add of existing embedding ID: NCVS0203
# Add of existing embedding ID: NCVS0204
# Add of existing embedding ID: NCVS0205
# Add of existing embedding ID: NCVS0206
# Add of existing embedding ID: NCVS0207
# Add of existing embedding ID: NCVS0208
# Add of existing embedding ID: NCVS0209
# Add of existing embedding ID: NCVS0210
# Add of existing embedding ID: NCVS0211
# Add of existing embedding ID: NCVS0212
# Add of existing embedding ID: NCVS0213
# Add of existing embedding ID: NCVS0214
# Add of existing embedding ID: NCVS0215
# Add of existing embedding ID: NCVS0216
# Add of existing embedding ID: NCVS0217
# Add of existing embedding ID: NCVS0218
# Add of existing embedding ID: NCVS0219
# Add of existing embedding ID: NCVS0220
# Add of existing embedding ID: NCVS0221
# Add of existing embedding ID: NCVS0222
# Add of existing embedding ID: NCVS0223
# Add of existing embedding ID: NCVS0224
# Add of existing embedding ID: NCVS0225
# Add of existing embedding ID: NCVS0226
# Add of existing embedding ID: NCVS0227
# Add of existing embedding ID: NCVS0228
# Add of existing embedding ID: NCVS0229
# Add of existing embedding ID: NCVS0230
# Add of existing embedding ID: NCVS0231
# Add of existing embedding ID: NCVS0232
# Add of existing embedding ID: NCVS0233
# Add of existing embedding ID: NCVS0234
# Add of existing embedding ID: NCVS0235
# Add of existing embedding ID: NCVS0236
# Add of existing embedding ID: NCVS0237
# Add of existing embedding ID: NCVS0238
# Add of existing embedding ID: NCVS0239
# Add of existing embedding ID: NCVS0240
# Add of existing embedding ID: NCVS0241
# Add of existing embedding ID: NCVS0242
# Add of existing embedding ID: NCVS0243
# Add of existing embedding ID: NCVS0244
# Add of existing embedding ID: NCVS0245
# Add of existing embedding ID: NCVS0246
# Add of existing embedding ID: NCVS0247
# Add of existing embedding ID: NCVS0248
# Add of existing embedding ID: NCVS0249
# Add of existing embedding ID: NCVS0250
# Add of existing embedding ID: NCVS0251
# Add of existing embedding ID: NCVS0252
# Add of existing embedding ID: NCVS0253
# Add of existing embedding ID: NCVS0254
# Add of existing embedding ID: NCVS0255
# Add of existing embedding ID: NCVS0256
# Add of existing embedding ID: NCVS0257
# Add of existing embedding ID: NCVS0258
# Add of existing embedding ID: NCVS0259
# Add of existing embedding ID: NCVS0260
# Add of existing embedding ID: NCVS0261
# Add of existing embedding ID: NCVS0262
# Add of existing embedding ID: NCVS0263
# Add of existing embedding ID: NCVS0264
# Add of existing embedding ID: NCVS0265
# Add of existing embedding ID: NCVS0266
# Add of existing embedding ID: NCVS0267
# Add of existing embedding ID: NCVS0268
# Add of existing embedding ID: NCVS0269
# Add of existing embedding ID: NCVS0270
# Add of existing embedding ID: NCVS0271
# Add of existing embedding ID: NCVS0272
# Add of existing embedding ID: NCVS0273
# Add of existing embedding ID: NCVS0274
# Add of existing embedding ID: NCVS0275
# Add of existing embedding ID: NCVS0276
# Add of existing embedding ID: NCVS0277
# Add of existing embedding ID: NCVS0278
# Add of existing embedding ID: NCVS0279
# Add of existing embedding ID: NCVS0280
# Add of existing embedding ID: NCVS0281
# Add of existing embedding ID: NCVS0282
# Add of existing embedding ID: NCVS0283
# Add of existing embedding ID: NCVS0284
# Add of existing embedding ID: NCVS0285
# Add of existing embedding ID: NCVS0286
# Add of existing embedding ID: NCVS0287
# Add of existing embedding ID: NCVS0288
# Add of existing embedding ID: NCVS0289
# Add of existing embedding ID: NCVS0290
# Add of existing embedding ID: NCVS0291
# Add of existing embedding ID: NCVS0292
# Add of existing embedding ID: NCVS0293
# Add of existing embedding ID: NCVS0294
# Add of existing embedding ID: NCVS0295
# Add of existing embedding ID: NCVS0296
# Add of existing embedding ID: NCVS0297
# Add of existing embedding ID: NCVS0298
# Add of existing embedding ID: NCVS0299
# Add of existing embedding ID: NCVS0300
# Add of existing embedding ID: NCVS0301
# Add of existing embedding ID: NCVS0302
# Add of existing embedding ID: NCVS0303
# Add of existing embedding ID: NCVS0304
# Add of existing embedding ID: NCVS0305
# Add of existing embedding ID: NCVS0306
# Add of existing embedding ID: NCVS0307
# Add of existing embedding ID: NCVS0308
# Add of existing embedding ID: NCVS0309
# Add of existing embedding ID: NCVS0310
# Add of existing embedding ID: NCVS0311
# Add of existing embedding ID: NCVS0312
# Add of existing embedding ID: NCVS0313
# Add of existing embedding ID: NCVS0314
# Add of existing embedding ID: NCVS0315
# Add of existing embedding ID: NCVS0316
# Add of existing embedding ID: NCVS0317
# Add of existing embedding ID: NCVS0318
# Add of existing embedding ID: NCVS0319
# Add of existing embedding ID: NCVS0320
# Add of existing embedding ID: NCVS0321
# Add of existing embedding ID: NCVS0322
# Add of existing embedding ID: NCVS0323
# Add of existing embedding ID: NCVS0324
# Add of existing embedding ID: NCVS0325
# Add of existing embedding ID: NCVS0326
# Add of existing embedding ID: NCVS0327
# Add of existing embedding ID: NCVS0328
# Add of existing embedding ID: NCVS0329
# Add of existing embedding ID: NCVS0330
# Add of existing embedding ID: NCVS0331
# Add of existing embedding ID: NCVS0332
# Add of existing embedding ID: NCVS0333
# Add of existing embedding ID: NCVS0334
# Add of existing embedding ID: NCVS0335
# Add of existing embedding ID: NCVS0336
# Add of existing embedding ID: NCVS0337
# Add of existing embedding ID: NCVS0338
# Add of existing embedding ID: NCVS0339
# Add of existing embedding ID: NCVS0340
# Add of existing embedding ID: NCVS0341
# Add of existing embedding ID: NCVS0342
# Add of existing embedding ID: NCVS0343
# Add of existing embedding ID: NCVS0344
# Add of existing embedding ID: NCVS0345
# Add of existing embedding ID: NCVS0346
# Add of existing embedding ID: NCVS0347
# Add of existing embedding ID: NCVS0348
# Add of existing embedding ID: NCVS0349
# Add of existing embedding ID: NCVS0350
# Add of existing embedding ID: NCVS0351
# Add of existing embedding ID: NCVS0352
# Add of existing embedding ID: NCVS0353
# Add of existing embedding ID: NCVS0354
# Add of existing embedding ID: NCVS0355
# Add of existing embedding ID: NCVS0356
# Add of existing embedding ID: NCVS0357
# Add of existing embedding ID: NCVS0358
# Add of existing embedding ID: NCVS0359
# Add of existing embedding ID: NCVS0360
# Add of existing embedding ID: NCVS0361
# Add of existing embedding ID: NCVS0362
# Add of existing embedding ID: NCVS0363
# Add of existing embedding ID: NCVS0364
# Add of existing embedding ID: NCVS0365
# Add of existing embedding ID: NCVS0366
# Add of existing embedding ID: NCVS0367
# Add of existing embedding ID: NCVS0368
# Add of existing embedding ID: NCVS0369
# Add of existing embedding ID: NCVS0370
# Add of existing embedding ID: NCVS0371
# Add of existing embedding ID: NCVS0372
# Add of existing embedding ID: NCVS0373
# Add of existing embedding ID: NCVS0374
# Add of existing embedding ID: NCVS0375
# Add of existing embedding ID: NCVS0376
# Add of existing embedding ID: NCVS0377
# Add of existing embedding ID: NCVS0378
# Add of existing embedding ID: NCVS0379
# Add of existing embedding ID: NCVS0380
# Add of existing embedding ID: NCVS0381
# Add of existing embedding ID: NCVS0382
# Add of existing embedding ID: NCVS0383
# Add of existing embedding ID: NCVS0384
# Add of existing embedding ID: NCVS0385
# Add of existing embedding ID: NCVS0386
# Add of existing embedding ID: NCVS0387
# Add of existing embedding ID: NCVS0388
# Add of existing embedding ID: NCVS0389
# Add of existing embedding ID: NCVS0390
# Add of existing embedding ID: NCVS0391
# Add of existing embedding ID: NCVS0392
# Add of existing embedding ID: NCVS0393
# Add of existing embedding ID: NCVS0394
# Add of existing embedding ID: NCVS0395
# Add of existing embedding ID: NCVS0396
# Add of existing embedding ID: NCVS0397
# Add of existing embedding ID: NCVS0398
# Add of existing embedding ID: NCVS0399
# Add of existing embedding ID: NCVS0400
# Add of existing embedding ID: NCVS0401
# Add of existing embedding ID: NCVS0402
# Add of existing embedding ID: NCVS0403
# Add of existing embedding ID: NCVS0404
# Add of existing embedding ID: NCVS0405
# Add of existing embedding ID: NCVS0406
# Add of existing embedding ID: NCVS0407
# Add of existing embedding ID: NCVS0408
# Add of existing embedding ID: NCVS0409
# Add of existing embedding ID: NCVS0410
# Add of existing embedding ID: NCVS0411
# Add of existing embedding ID: NCVS0412
# Add of existing embedding ID: NCVS0413
# Add of existing embedding ID: NCVS0414
# Add of existing embedding ID: NCVS0415
# Add of existing embedding ID: NCVS0416
# Add of existing embedding ID: NCVS0417
# Add of existing embedding ID: NCVS0418
# Add of existing embedding ID: NCVS0419
# Add of existing embedding ID: NCVS0420
# Add of existing embedding ID: NCVS0421
# Add of existing embedding ID: NCVS0422
# Add of existing embedding ID: NCVS0423
# Add of existing embedding ID: NCVS0424
# Add of existing embedding ID: NCVS0425
# Add of existing embedding ID: NCVS0426
# Add of existing embedding ID: NCVS0427
# Add of existing embedding ID: NCVS0428
# Add of existing embedding ID: NCVS0429
# Add of existing embedding ID: NCVS0430
# Add of existing embedding ID: NCVS0431
# Add of existing embedding ID: NCVS0432
# Add of existing embedding ID: NCVS0433
# Add of existing embedding ID: NCVS0434
# Add of existing embedding ID: NCVS0435
# Add of existing embedding ID: NCVS0436
# Add of existing embedding ID: NCVS0437
# Add of existing embedding ID: NCVS0438
# Add of existing embedding ID: NCVS0439
# Add of existing embedding ID: NCVS0440
# Add of existing embedding ID: NCVS0441
# Add of existing embedding ID: NCVS0442
# Add of existing embedding ID: NCVS0443
# Add of existing embedding ID: NCVS0444
# Add of existing embedding ID: NCVS0445
# Add of existing embedding ID: NCVS0446
# Add of existing embedding ID: NCVS0447
# Add of existing embedding ID: NCVS0448
# Add of existing embedding ID: NCVS0449
# Add of existing embedding ID: NCVS0450
# Add of existing embedding ID: NCVS0451
# Add of existing embedding ID: NCVS0452
# Add of existing embedding ID: NCVS0453
# Add of existing embedding ID: NCVS0454
# Add of existing embedding ID: NCVS0455
# Add of existing embedding ID: NCVS0456
# Add of existing embedding ID: NCVS0457
# Add of existing embedding ID: NCVS0458
# Add of existing embedding ID: NCVS0459
# Add of existing embedding ID: NCVS0460
# Add of existing embedding ID: NCVS0461
# Add of existing embedding ID: NCVS0462
# Add of existing embedding ID: NCVS0463
# Add of existing embedding ID: NCVS0464
# Add of existing embedding ID: NCVS0465
# Add of existing embedding ID: NCVS0466
# Add of existing embedding ID: NCVS0467
# Add of existing embedding ID: NCVS0468
# Add of existing embedding ID: NCVS0469
# Add of existing embedding ID: NCVS0470
# Add of existing embedding ID: NCVS0471
# Add of existing embedding ID: NCVS0472
# Add of existing embedding ID: NCVS0473
# Add of existing embedding ID: NCVS0474
# Add of existing embedding ID: NCVS0475
# Add of existing embedding ID: NCVS0476
# Add of existing embedding ID: NCVS0477
# Add of existing embedding ID: NCVS0478
# Add of existing embedding ID: NCVS0479
# Add of existing embedding ID: NCVS0480
# Add of existing embedding ID: NCVS0481
# Add of existing embedding ID: NCVS0482
# Add of existing embedding ID: NCVS0483
# Add of existing embedding ID: NCVS0484
# Add of existing embedding ID: NCVS0485
# Add of existing embedding ID: NCVS0486
# Add of existing embedding ID: NCVS0487
# Add of existing embedding ID: NCVS0488
# Add of existing embedding ID: NCVS0489
# Add of existing embedding ID: NCVS0490
# Add of existing embedding ID: NCVS0491
# Add of existing embedding ID: NCVS0492
# Add of existing embedding ID: NCVS0493
# Add of existing embedding ID: NCVS0494
# Add of existing embedding ID: NCVS0495
# Add of existing embedding ID: NCVS0496
# Add of existing embedding ID: NCVS0497
# Add of existing embedding ID: NCVS0498
# Add of existing embedding ID: NCVS0499
# Add of existing embedding ID: NCVS0500
# Add of existing embedding ID: NCVS0501
# Add of existing embedding ID: NCVS0502
# Add of existing embedding ID: NCVS0503
# Add of existing embedding ID: NCVS0504
# Add of existing embedding ID: NCVS0505
# Add of existing embedding ID: NCVS0506
# Add of existing embedding ID: NCVS0507
# Add of existing embedding ID: NCVS0508
# Add of existing embedding ID: NCVS0509
# Add of existing embedding ID: NCVS0510
# Add of existing embedding ID: NCVS0511
# Add of existing embedding ID: NCVS0512
# Add of existing embedding ID: NCVS0513
# Add of existing embedding ID: NCVS0514
# Add of existing embedding ID: NCVS0515
# Add of existing embedding ID: NCVS0516
# Add of existing embedding ID: NCVS0517
# Add of existing embedding ID: NCVS0518
# Add of existing embedding ID: NCVS0519
# Add of existing embedding ID: NCVS0520
# Add of existing embedding ID: NCVS0521
# Add of existing embedding ID: NCVS0522
# Add of existing embedding ID: NCVS0523
# Add of existing embedding ID: NCVS0524
# Add of existing embedding ID: NCVS0525
# Add of existing embedding ID: NCVS0526
# Add of existing embedding ID: NCVS0527
# Add of existing embedding ID: NCVS0528
# Add of existing embedding ID: NCVS0529
# Add of existing embedding ID: NCVS0530
# Add of existing embedding ID: NCVS0531
# Add of existing embedding ID: NCVS0532
# Add of existing embedding ID: NCVS0533
# Add of existing embedding ID: NCVS0534
# Add of existing embedding ID: NCVS0535
# Add of existing embedding ID: NCVS0536
# Add of existing embedding ID: NCVS0537
# Add of existing embedding ID: NCVS0538
# Add of existing embedding ID: NCVS0539
# Add of existing embedding ID: NCVS0540
# Add of existing embedding ID: NCVS0541
# Add of existing embedding ID: NCVS0542
# Add of existing embedding ID: NCVS0543
# Add of existing embedding ID: NCVS0544
# Add of existing embedding ID: NCVS0545
# Add of existing embedding ID: NCVS0546
# Add of existing embedding ID: NCVS0547
# Add of existing embedding ID: NCVS0548
# Add of existing embedding ID: NCVS0549
# Add of existing embedding ID: NCVS0550
# Add of existing embedding ID: NCVS0551
# Add of existing embedding ID: NCVS0552
# Add of existing embedding ID: NCVS0553
# Add of existing embedding ID: NCVS0554
# Add of existing embedding ID: NCVS0555
# Add of existing embedding ID: NCVS0556
# Add of existing embedding ID: NCVS0557
# Add of existing embedding ID: NCVS0558
# Add of existing embedding ID: NCVS0559
# Add of existing embedding ID: NCVS0560
# Add of existing embedding ID: NCVS0561
# Add of existing embedding ID: NCVS0562
# Add of existing embedding ID: NCVS0563
# Add of existing embedding ID: NCVS0564
# Add of existing embedding ID: NCVS0565
# Add of existing embedding ID: NCVS0566
# Add of existing embedding ID: NCVS0567
# Add of existing embedding ID: NCVS0568
# Add of existing embedding ID: NCVS0569
# Add of existing embedding ID: NCVS0570
# Add of existing embedding ID: NCVS0571
# Add of existing embedding ID: NCVS0572
# Add of existing embedding ID: NCVS0573
# Add of existing embedding ID: NCVS0574
# Add of existing embedding ID: NCVS0575
# Add of existing embedding ID: NCVS0576
# Add of existing embedding ID: NCVS0577
# Add of existing embedding ID: NCVS0578
# Add of existing embedding ID: NCVS0579
# Add of existing embedding ID: NCVS0580
# Add of existing embedding ID: NCVS0581
# Add of existing embedding ID: NCVS0582
# Add of existing embedding ID: NCVS0583
# Add of existing embedding ID: NCVS0584
# Add of existing embedding ID: NCVS0585
# Add of existing embedding ID: NCVS0586
# Add of existing embedding ID: NCVS0587
# Add of existing embedding ID: NCVS0588
# Add of existing embedding ID: NCVS0589
# Add of existing embedding ID: NCVS0590
# Add of existing embedding ID: NCVS0591
# Add of existing embedding ID: NCVS0592
# Add of existing embedding ID: NCVS0593
# Add of existing embedding ID: NCVS0594
# Add of existing embedding ID: NCVS0595
# Add of existing embedding ID: NCVS0596
# Add of existing embedding ID: NCVS0597
# Add of existing embedding ID: NCVS0598
# Add of existing embedding ID: NCVS0599
# Add of existing embedding ID: NCVS0600
# Add of existing embedding ID: NCVS0601
# Add of existing embedding ID: NCVS0602
# Add of existing embedding ID: NCVS0603
# Add of existing embedding ID: NCVS0604
# Add of existing embedding ID: NCVS0605
# Add of existing embedding ID: NCVS0606
# Add of existing embedding ID: NCVS0607
# Add of existing embedding ID: NCVS0608
# Add of existing embedding ID: NCVS0609
# Add of existing embedding ID: NCVS0610
# Add of existing embedding ID: NCVS0611
# Add of existing embedding ID: NCVS0612
# Add of existing embedding ID: NCVS0613
# Add of existing embedding ID: NCVS0614
# Add of existing embedding ID: NCVS0615
# Add of existing embedding ID: NCVS0616
# Add of existing embedding ID: NCVS0617
# Add of existing embedding ID: NCVS0618
# Add of existing embedding ID: NCVS0619
# Add of existing embedding ID: NCVS0620
# Add of existing embedding ID: NCVS0621
# Add of existing embedding ID: NCVS0622
# Add of existing embedding ID: NCVS0623
# Add of existing embedding ID: NCVS0624
# Add of existing embedding ID: NCVS0625
# Add of existing embedding ID: NCVS0626
# Add of existing embedding ID: NCVS0627
# Add of existing embedding ID: NCVS0628
# Add of existing embedding ID: NCVS0629
# Add of existing embedding ID: NCVS0630
# Add of existing embedding ID: NCVS0631
# Add of existing embedding ID: NCVS0632
# Add of existing embedding ID: NCVS0633
# Add of existing embedding ID: NCVS0634
# Add of existing embedding ID: NCVS0635
# Add of existing embedding ID: NCVS0636
# Add of existing embedding ID: NCVS0637
# Add of existing embedding ID: NCVS0638
# Add of existing embedding ID: NCVS0639
# Add of existing embedding ID: NCVS0640
# Add of existing embedding ID: NCVS0641
# Add of existing embedding ID: NCVS0642
# Add of existing embedding ID: NCVS0643
# Add of existing embedding ID: NCVS0644
# Add of existing embedding ID: NCVS0645
# Add of existing embedding ID: NCVS0646
# Add of existing embedding ID: NCVS0647
# Add of existing embedding ID: NCVS0648
# Add of existing embedding ID: NCVS0649
# Add of existing embedding ID: NCVS0650
# Add of existing embedding ID: NCVS0651
# Add of existing embedding ID: NCVS0652
# Add of existing embedding ID: NCVS0653
# Add of existing embedding ID: NCVS0654
# Add of existing embedding ID: NCVS0655
# Add of existing embedding ID: NCVS0656
# Add of existing embedding ID: NCVS0657
# Add of existing embedding ID: NCVS0658
# Add of existing embedding ID: NCVS0659
# Add of existing embedding ID: NCVS0660
# Add of existing embedding ID: NCVS0661
# Add of existing embedding ID: NCVS0662
# Add of existing embedding ID: NCVS0663
# Add of existing embedding ID: NCVS0664
# Add of existing embedding ID: NCVS0665
# Add of existing embedding ID: NCVS0666
# Add of existing embedding ID: NCVS0667
# Add of existing embedding ID: NCVS0668
# Add of existing embedding ID: NCVS0669
# Add of existing embedding ID: NCVS0670
# Add of existing embedding ID: NCVS0671
# Add of existing embedding ID: NCVS0672
# Add of existing embedding ID: NCVS0673
# Add of existing embedding ID: NCVS0674
# Add of existing embedding ID: NCVS0675
# Add of existing embedding ID: NCVS0676
# Add of existing embedding ID: NCVS0677
# Add of existing embedding ID: NCVS0678
# Add of existing embedding ID: NCVS0679
# Add of existing embedding ID: NCVS0680
# Add of existing embedding ID: NCVS0681
# Add of existing embedding ID: NCVS0682
# Add of existing embedding ID: NCVS0683
# Add of existing embedding ID: NCVS0684
# Add of existing embedding ID: NCVS0685
# Add of existing embedding ID: NCVS0686
# Add of existing embedding ID: NCVS0687
# Add of existing embedding ID: NCVS0688
# Add of existing embedding ID: NCVS0689
# Add of existing embedding ID: NCVS0690
# Add of existing embedding ID: NCVS0691
# Add of existing embedding ID: NCVS0692
# Add of existing embedding ID: NCVS0693
# Add of existing embedding ID: NCVS0694
# Add of existing embedding ID: NCVS0695
# Add of existing embedding ID: NCVS0696
# Add of existing embedding ID: NCVS0697
# Add of existing embedding ID: NCVS0698
# Add of existing embedding ID: NCVS0699
# Add of existing embedding ID: NCVS0700
# Add of existing embedding ID: NCVS0701
# Add of existing embedding ID: NCVS0702
# Add of existing embedding ID: NCVS0703
# Add of existing embedding ID: NCVS0704
# Add of existing embedding ID: NCVS0705
# Add of existing embedding ID: NCVS0706
# Add of existing embedding ID: NCVS0707
# Add of existing embedding ID: NCVS0708
# Add of existing embedding ID: NCVS0709
# Add of existing embedding ID: NCVS0710
# Add of existing embedding ID: NCVS0711
# Add of existing embedding ID: NCVS0712
# Add of existing embedding ID: NCVS0713
# Add of existing embedding ID: NCVS0714
# Add of existing embedding ID: NCVS0715
# Add of existing embedding ID: NCVS0716
# Add of existing embedding ID: NCVS0717
# Add of existing embedding ID: NCVS0718
# Add of existing embedding ID: NCVS0719
# Add of existing embedding ID: NCVS0720
# Add of existing embedding ID: NCVS0721
# Add of existing embedding ID: NCVS0722
# Add of existing embedding ID: NCVS0723
# Add of existing embedding ID: NCVS0724
# Add of existing embedding ID: NCVS0725
# Add of existing embedding ID: NCVS0726
# Add of existing embedding ID: NCVS0727
# Add of existing embedding ID: NCVS0728
# Add of existing embedding ID: NCVS0729
# Add of existing embedding ID: NCVS0730
# Add of existing embedding ID: NCVS0731
# Add of existing embedding ID: NCVS0732
# Add of existing embedding ID: NCVS0733
# Add of existing embedding ID: NCVS0734
# Add of existing embedding ID: NCVS0735
# Add of existing embedding ID: NCVS0736
# Add of existing embedding ID: NCVS0737
# Add of existing embedding ID: NCVS0738
# Add of existing embedding ID: NCVS0739
# Add of existing embedding ID: NCVS0740
# Add of existing embedding ID: NCVS0741
# Add of existing embedding ID: NCVS0742
# Add of existing embedding ID: NCVS0743
# Add of existing embedding ID: NCVS0744
# Add of existing embedding ID: NCVS0745
# Add of existing embedding ID: NCVS0746
# Add of existing embedding ID: NCVS0747
# Add of existing embedding ID: NCVS0748
# Add of existing embedding ID: NCVS0749
# Add of existing embedding ID: NCVS0750
# Add of existing embedding ID: NCVS0751
# Add of existing embedding ID: NCVS0752
# Add of existing embedding ID: NCVS0753
# Add of existing embedding ID: NCVS0754
# Add of existing embedding ID: NCVS0755
# Add of existing embedding ID: NCVS0756
# Add of existing embedding ID: NCVS0757
# Add of existing embedding ID: NCVS0758
# Add of existing embedding ID: NCVS0759
# Add of existing embedding ID: NCVS0760
# Add of existing embedding ID: NCVS0761
# Add of existing embedding ID: NCVS0762
# Add of existing embedding ID: NCVS0763
# Add of existing embedding ID: NCVS0764
# Add of existing embedding ID: NCVS0765
# Add of existing embedding ID: NCVS0766
# Add of existing embedding ID: NCVS0767
# Add of existing embedding ID: NCVS0768
# Add of existing embedding ID: NCVS0769
# Add of existing embedding ID: NCVS0770
# Add of existing embedding ID: NCVS0771
# Add of existing embedding ID: NCVS0772
# Add of existing embedding ID: NCVS0773
# Add of existing embedding ID: NCVS0774
# Add of existing embedding ID: NCVS0775
# Add of existing embedding ID: NCVS0776
# Add of existing embedding ID: NCVS0777
# Add of existing embedding ID: NCVS0778
# Add of existing embedding ID: NCVS0779
# Add of existing embedding ID: NCVS0780
# Add of existing embedding ID: NCVS0781
# Add of existing embedding ID: NCVS0782
# Add of existing embedding ID: NCVS0783
# Add of existing embedding ID: NCVS0784
# Add of existing embedding ID: NCVS0785
# Add of existing embedding ID: NCVS0786
# Add of existing embedding ID: NCVS0787
# Add of existing embedding ID: NCVS0788
# Add of existing embedding ID: NCVS0789
# Add of existing embedding ID: NCVS0790
# Add of existing embedding ID: NCVS0791
# Add of existing embedding ID: NCVS0792
# Add of existing embedding ID: NCVS0793
# Add of existing embedding ID: NCVS0794
# Add of existing embedding ID: NCVS0795
# Add of existing embedding ID: NCVS0796
# Add of existing embedding ID: NCVS0797
# Add of existing embedding ID: NCVS0798
# Add of existing embedding ID: NCVS0799
# Add of existing embedding ID: NCVS0800
# Add of existing embedding ID: NCVS0801
# Add of existing embedding ID: NCVS0802
# Add of existing embedding ID: NCVS0803
# Add of existing embedding ID: NCVS0804
# Add of existing embedding ID: NCVS0805
# Add of existing embedding ID: NCVS0806
# Add of existing embedding ID: NCVS0807
# Add of existing embedding ID: NCVS0808
# Add of existing embedding ID: NCVS0809
# Add of existing embedding ID: NCVS0810
# Add of existing embedding ID: NCVS0811
# Add of existing embedding ID: NCVS0812
# Add of existing embedding ID: NCVS0813
# Add of existing embedding ID: NCVS0814
# Add of existing embedding ID: NCVS0815
# Add of existing embedding ID: NCVS0816
# Add of existing embedding ID: NCVS0817
# Add of existing embedding ID: NCVS0818
# Add of existing embedding ID: NCVS0819
# Add of existing embedding ID: NCVS0820
# Add of existing embedding ID: NCVS0821
# Add of existing embedding ID: NCVS0822
# Add of existing embedding ID: NCVS0823
# Add of existing embedding ID: NCVS0824
# Add of existing embedding ID: NCVS0825
# Add of existing embedding ID: NCVS0826
# Add of existing embedding ID: NCVS0827
# Add of existing embedding ID: NCVS0828
# Add of existing embedding ID: NCVS0829
# Add of existing embedding ID: NCVS0830
# Add of existing embedding ID: NCVS0831
# Add of existing embedding ID: NCVS0832
# Add of existing embedding ID: NCVS0833
# Add of existing embedding ID: NCVS0834
# Add of existing embedding ID: NCVS0835
# Add of existing embedding ID: NCVS0836
# Add of existing embedding ID: NCVS0837
# Add of existing embedding ID: NCVS0838
# Add of existing embedding ID: NCVS0839
# Add of existing embedding ID: NCVS0840
# Add of existing embedding ID: NCVS0841
# Add of existing embedding ID: NCVS0842
# Add of existing embedding ID: NCVS0843
# Add of existing embedding ID: NCVS0844
# Add of existing embedding ID: NCVS0845
# Add of existing embedding ID: NCVS0846
# Add of existing embedding ID: NCVS0847
# Add of existing embedding ID: NCVS0848
# Add of existing embedding ID: NCVS0849
# Add of existing embedding ID: NCVS0850
# Add of existing embedding ID: NCVS0851
# Add of existing embedding ID: NCVS0852
# Add of existing embedding ID: NCVS0853
# Add of existing embedding ID: NCVS0854
# Add of existing embedding ID: NCVS0855
# Add of existing embedding ID: NCVS0856
# Add of existing embedding ID: NCVS0857
# Add of existing embedding ID: NCVS0858
# Add of existing embedding ID: NCVS0859
# Add of existing embedding ID: NCVS0860
# Add of existing embedding ID: NCVS0861
# Add of existing embedding ID: NCVS0862
# Add of existing embedding ID: NCVS0863
# Add of existing embedding ID: NCVS0864
# Add of existing embedding ID: NCVS0865
# Add of existing embedding ID: NCVS0866
# Add of existing embedding ID: NCVS0867
# Add of existing embedding ID: NCVS0868
# Add of existing embedding ID: NCVS0869
# Add of existing embedding ID: NCVS0870
# Add of existing embedding ID: NCVS0871
# Add of existing embedding ID: NCVS0872
# Add of existing embedding ID: NCVS0873
# Add of existing embedding ID: NCVS0874
# Add of existing embedding ID: NCVS0875
# Add of existing embedding ID: NCVS0876
# Add of existing embedding ID: NCVS0877
# Add of existing embedding ID: NCVS0878
# Add of existing embedding ID: NCVS0879
# Add of existing embedding ID: NCVS0880
# Add of existing embedding ID: NCVS0881
# Add of existing embedding ID: NCVS0882
# Add of existing embedding ID: NCVS0883
# Add of existing embedding ID: NCVS0884
# Add of existing embedding ID: NCVS0885
# Add of existing embedding ID: NCVS0886
# Add of existing embedding ID: NCVS0887
# Add of existing embedding ID: NCVS0888
# Add of existing embedding ID: NCVS0889
# Add of existing embedding ID: NCVS0890
# Add of existing embedding ID: NCVS0891
# Add of existing embedding ID: NCVS0892
# Add of existing embedding ID: NCVS0893
# Add of existing embedding ID: NCVS0894
# Add of existing embedding ID: NCVS0895
# Add of existing embedding ID: NCVS0896
# Add of existing embedding ID: NCVS0897
# Add of existing embedding ID: NCVS0898
# Add of existing embedding ID: NCVS0899
# Add of existing embedding ID: NCVS0900
# Add of existing embedding ID: NCVS0901
# Add of existing embedding ID: NCVS0902
# Add of existing embedding ID: NCVS0903
# Add of existing embedding ID: NCVS0904
# Add of existing embedding ID: NCVS0905
# Add of existing embedding ID: NCVS0906
# Add of existing embedding ID: NCVS0907
# Add of existing embedding ID: NCVS0908
# Add of existing embedding ID: NCVS0909
# Add of existing embedding ID: NCVS0910
# Add of existing embedding ID: NCVS0911
# Add of existing embedding ID: NCVS0912
# Add of existing embedding ID: NCVS0913
# Add of existing embedding ID: NCVS0914
# Add of existing embedding ID: NCVS0915
# Add of existing embedding ID: NCVS0916
# Add of existing embedding ID: NCVS0917
# Add of existing embedding ID: NCVS0918
# Add of existing embedding ID: NCVS0919
# Add of existing embedding ID: NCVS0920
# Add of existing embedding ID: NCVS0921
# Add of existing embedding ID: NCVS0922
# Add of existing embedding ID: NCVS0923
# Add of existing embedding ID: NCVS0924
# Add of existing embedding ID: NCVS0925
# Add of existing embedding ID: NCVS0926
# Add of existing embedding ID: NCVS0927
# Add of existing embedding ID: NCVS0928
# Add of existing embedding ID: NCVS0929
# Add of existing embedding ID: NCVS0930
# Add of existing embedding ID: NCVS0931
# Add of existing embedding ID: NCVS0932
# Add of existing embedding ID: NCVS0933
# Add of existing embedding ID: NCVS0934
# Add of existing embedding ID: NCVS0935
# Add of existing embedding ID: NCVS0936
# Add of existing embedding ID: NCVS0937
# Add of existing embedding ID: NCVS0938
# Add of existing embedding ID: NCVS0939
# Add of existing embedding ID: NCVS0940
# Add of existing embedding ID: NCVS0941
# Add of existing embedding ID: NCVS0942
# Add of existing embedding ID: NCVS0943
# Add of existing embedding ID: NCVS0944
# Add of existing embedding ID: NCVS0945
# Add of existing embedding ID: NCVS0946
# Add of existing embedding ID: NCVS0947
# Add of existing embedding ID: NCVS0948
# Add of existing embedding ID: NCVS0949
# Add of existing embedding ID: NCVS0950
# Add of existing embedding ID: NCVS0951
# Add of existing embedding ID: NCVS0952
# Add of existing embedding ID: NCVS0953
# Add of existing embedding ID: NCVS0954
# Add of existing embedding ID: NCVS0955
# Add of existing embedding ID: NCVS0956
# Add of existing embedding ID: NCVS0957
# Add of existing embedding ID: NCVS0958
# Add of existing embedding ID: NCVS0959
# Add of existing embedding ID: NCVS0960
# Add of existing embedding ID: NCVS0961
# Add of existing embedding ID: NCVS0962
# Add of existing embedding ID: NCVS0963
# Add of existing embedding ID: NCVS0964
# Add of existing embedding ID: NCVS0965
# Add of existing embedding ID: NCVS0966
# Add of existing embedding ID: NCVS0967
# Add of existing embedding ID: NCVS0968
# Add of existing embedding ID: NCVS0969
# Add of existing embedding ID: NCVS0970
# Add of existing embedding ID: NCVS0971
# Add of existing embedding ID: NCVS0972
# Add of existing embedding ID: NCVS0973
# Add of existing embedding ID: NCVS0974
# Add of existing embedding ID: NCVS0975
# Add of existing embedding ID: NCVS0976
# Add of existing embedding ID: NCVS0977
# Add of existing embedding ID: NCVS0978
# Add of existing embedding ID: NCVS0979
# Add of existing embedding ID: NCVS0980
# Add of existing embedding ID: NCVS0981
# Add of existing embedding ID: NCVS0982
# Add of existing embedding ID: NCVS0983
# Add of existing embedding ID: NCVS0984
# Add of existing embedding ID: NCVS0985
# Add of existing embedding ID: NCVS0986
# Add of existing embedding ID: NCVS0987
# Add of existing embedding ID: NCVS0988
# Add of existing embedding ID: NCVS0989
# Add of existing embedding ID: NCVS0990
# Add of existing embedding ID: NCVS0991
# Add of existing embedding ID: NCVS0992
# Add of existing embedding ID: NCVS0993
# Add of existing embedding ID: NCVS0994
# Add of existing embedding ID: NCVS0995
# Add of existing embedding ID: NCVS0996
# Add of existing embedding ID: NCVS0997
# Add of existing embedding ID: NCVS0998
# Add of existing embedding ID: NCVS0999
# Add of existing embedding ID: NCVS1000
# Add of existing embedding ID: NCVS1001
# Add of existing embedding ID: NCVS1002
# Add of existing embedding ID: NCVS1003
# Add of existing embedding ID: NCVS1004
# Add of existing embedding ID: NCVS1005
# Add of existing embedding ID: NCVS1006
# Add of existing embedding ID: NCVS1007
# Add of existing embedding ID: NCVS1008
# Add of existing embedding ID: NCVS1009
# Add of existing embedding ID: NCVS1010
# Add of existing embedding ID: NCVS1011
# Add of existing embedding ID: NCVS1012
# Add of existing embedding ID: NCVS1013
# Add of existing embedding ID: NCVS1014
# Add of existing embedding ID: NCVS1015
# Add of existing embedding ID: NCVS1016
# Add of existing embedding ID: NCVS1017
# Add of existing embedding ID: NCVS1018
# Add of existing embedding ID: NCVS1019
# Add of existing embedding ID: NCVS1020
# Add of existing embedding ID: NCVS1021
# Add of existing embedding ID: NCVS1022
# Add of existing embedding ID: NCVS1023
# Add of existing embedding ID: NCVS1024
# Add of existing embedding ID: NCVS1025
# Add of existing embedding ID: NCVS1026
# Add of existing embedding ID: NCVS1027
# Add of existing embedding ID: NCVS1028
# Add of existing embedding ID: NCVS1029
# Add of existing embedding ID: NCVS1030
# Add of existing embedding ID: NCVS1031
# Add of existing embedding ID: NCVS1032
# Add of existing embedding ID: NCVS1033
# Add of existing embedding ID: NCVS1034
# Add of existing embedding ID: NCVS1035
# Add of existing embedding ID: NCVS1036
# Add of existing embedding ID: NCVS1037
# Add of existing embedding ID: NCVS1038
# Add of existing embedding ID: NCVS1039
# Add of existing embedding ID: NCVS1040
# Add of existing embedding ID: NCVS1041
# Add of existing embedding ID: NCVS1042
# Add of existing embedding ID: NCVS1043
# Add of existing embedding ID: NCVS1044
# Add of existing embedding ID: NCVS1045
# Add of existing embedding ID: NCVS1046
# Add of existing embedding ID: NCVS1047
# Add of existing embedding ID: NCVS1048
# Add of existing embedding ID: NCVS1049
# Add of existing embedding ID: NCVS1050
# Add of existing embedding ID: NCVS1051
# Add of existing embedding ID: NCVS1052
# Add of existing embedding ID: NCVS1053
# Add of existing embedding ID: NCVS1054
# Add of existing embedding ID: NCVS1055
# Add of existing embedding ID: NCVS1056
# Add of existing embedding ID: NCVS1057
# Add of existing embedding ID: NCVS1058
# Add of existing embedding ID: NCVS1059
# Add of existing embedding ID: NCVS1060
# Add of existing embedding ID: NCVS1061
# Add of existing embedding ID: NCVS1062
# Add of existing embedding ID: NCVS1063
# Add of existing embedding ID: NCVS1064
# Add of existing embedding ID: NCVS1065
# Add of existing embedding ID: NCVS1066
# Add of existing embedding ID: NCVS1067
# Add of existing embedding ID: NCVS1068
# Add of existing embedding ID: NCVS1069
# Add of existing embedding ID: NCVS1070
# Add of existing embedding ID: NCVS1071
# Add of existing embedding ID: NCVS1072
# Add of existing embedding ID: NCVS1073
# Add of existing embedding ID: NCVS1074
# Add of existing embedding ID: NCVS1075
# Add of existing embedding ID: NCVS1076
# Add of existing embedding ID: NCVS1077
# Add of existing embedding ID: NCVS1078
# Add of existing embedding ID: NCVS1079
# Add of existing embedding ID: NCVS1080
# Add of existing embedding ID: NCVS1081
# Add of existing embedding ID: NCVS1082
# Add of existing embedding ID: NCVS1083
# Add of existing embedding ID: NCVS1084
# Add of existing embedding ID: NCVS1085
# Add of existing embedding ID: NCVS1086
# Add of existing embedding ID: NCVS1087
# Add of existing embedding ID: NCVS1088
# Add of existing embedding ID: NCVS1089
# Add of existing embedding ID: NCVS1090
# Add of existing embedding ID: NCVS1091
# Add of existing embedding ID: NCVS1092
# Add of existing embedding ID: NCVS1093
# Add of existing embedding ID: NCVS1094
# Add of existing embedding ID: NCVS1095
# Add of existing embedding ID: NCVS1096
# Add of existing embedding ID: NCVS1097
# Add of existing embedding ID: NCVS1098
# Add of existing embedding ID: NCVS1099
# Add of existing embedding ID: NCVS1100
# Add of existing embedding ID: NCVS1101
# Add of existing embedding ID: NCVS1102
# Add of existing embedding ID: NCVS1103
# Add of existing embedding ID: NCVS1104
# Add of existing embedding ID: NCVS1105
# Add of existing embedding ID: NCVS1106
# Add of existing embedding ID: NCVS1107
# Add of existing embedding ID: NCVS1108
# Add of existing embedding ID: NCVS1109
# Add of existing embedding ID: NCVS1110
# Add of existing embedding ID: NCVS1111
# Add of existing embedding ID: NCVS1112
# Add of existing embedding ID: NCVS1113
# Add of existing embedding ID: NCVS1114
# Add of existing embedding ID: NCVS1115
# Add of existing embedding ID: NCVS1116
# Add of existing embedding ID: NCVS1117
# Add of existing embedding ID: NCVS1118
# Add of existing embedding ID: NCVS1119
# Add of existing embedding ID: NCVS1120
# Add of existing embedding ID: NCVS1121
# Add of existing embedding ID: NCVS1122
# Add of existing embedding ID: NCVS1123
# Add of existing embedding ID: NCVS1124
# Add of existing embedding ID: NCVS1125
# Add of existing embedding ID: NCVS1126
# Add of existing embedding ID: NCVS1127
# Add of existing embedding ID: NCVS1128
# Add of existing embedding ID: NCVS1129
# Add of existing embedding ID: NCVS1130
# Add of existing embedding ID: NCVS1131
# Add of existing embedding ID: NCVS1132
# Add of existing embedding ID: NCVS1133
# Add of existing embedding ID: NCVS1134
# Add of existing embedding ID: NCVS1135
# Add of existing embedding ID: NCVS1136
# Add of existing embedding ID: NCVS1137
# Add of existing embedding ID: NCVS1138
# Add of existing embedding ID: NCVS1139
# Add of existing embedding ID: NCVS1140
# Add of existing embedding ID: NCVS1141
# Add of existing embedding ID: NCVS1142
# Add of existing embedding ID: NCVS1143
# Add of existing embedding ID: NCVS1144
# Add of existing embedding ID: NCVS1145
# Add of existing embedding ID: NCVS1146
# Add of existing embedding ID: NCVS1147
# Add of existing embedding ID: NCVS1148
# Add of existing embedding ID: NCVS1149
# Add of existing embedding ID: NCVS1150
# Add of existing embedding ID: NCVS1151
# Add of existing embedding ID: NCVS1152
# Add of existing embedding ID: NCVS1153
# Add of existing embedding ID: NCVS1154
# Add of existing embedding ID: NCVS1155
# Add of existing embedding ID: NCVS1156
# Add of existing embedding ID: NCVS1157
# Add of existing embedding ID: NCVS1158
# Add of existing embedding ID: NCVS1159
# Add of existing embedding ID: NCVS1160
# Add of existing embedding ID: NCVS1161
# Add of existing embedding ID: NCVS1162
# Add of existing embedding ID: NCVS1163
# Add of existing embedding ID: NCVS1164
# Add of existing embedding ID: NCVS1165
# Add of existing embedding ID: NCVS1166
# Add of existing embedding ID: NCVS1167
# Add of existing embedding ID: NCVS1168
# Add of existing embedding ID: NCVS1169
# Add of existing embedding ID: NCVS1170
# Add of existing embedding ID: NCVS1171
# Add of existing embedding ID: NCVS1172
# Add of existing embedding ID: NCVS1173
# Add of existing embedding ID: NCVS1174
# Add of existing embedding ID: NCVS1175
# Add of existing embedding ID: NCVS1176
# Add of existing embedding ID: NCVS1177
# Add of existing embedding ID: NCVS1178
# Add of existing embedding ID: NCVS1179
# Add of existing embedding ID: NCVS1180
# Add of existing embedding ID: NCVS1181
# Add of existing embedding ID: NCVS1182
# Add of existing embedding ID: NCVS1183
# Add of existing embedding ID: NCVS1184
# Add of existing embedding ID: NCVS1185
# Add of existing embedding ID: NCVS1186
# Add of existing embedding ID: NCVS1187
# Add of existing embedding ID: NCVS1188
# Add of existing embedding ID: NCVS1189
# Add of existing embedding ID: NCVS1190
# Add of existing embedding ID: NCVS1191
# Add of existing embedding ID: NCVS1192
# Add of existing embedding ID: NCVS1193
# Add of existing embedding ID: NCVS1194
# Add of existing embedding ID: NCVS1195
# Add of existing embedding ID: NCVS1196
# Add of existing embedding ID: NCVS1197
# Add of existing embedding ID: NCVS1198
# Add of existing embedding ID: NCVS1199
# Add of existing embedding ID: NCVS1200
# Add of existing embedding ID: NCVS1201
# Add of existing embedding ID: NCVS1202
# Add of existing embedding ID: NCVS1203
# Add of existing embedding ID: NCVS1204
# Add of existing embedding ID: NCVS1205
# Add of existing embedding ID: NCVS1206
# Add of existing embedding ID: NCVS1207
# Add of existing embedding ID: NCVS1208
# Add of existing embedding ID: NCVS1209
# Add of existing embedding ID: NCVS1210
# Add of existing embedding ID: NCVS1211
# Add of existing embedding ID: NCVS1212
# Add of existing embedding ID: NCVS1213
# Add of existing embedding ID: NCVS1214
# Add of existing embedding ID: NCVS1215
# Add of existing embedding ID: NCVS1216
# Add of existing embedding ID: NCVS1217
# Add of existing embedding ID: NCVS1218
# Add of existing embedding ID: NCVS1219
# Add of existing embedding ID: NCVS1220
# Add of existing embedding ID: NCVS1221
# Add of existing embedding ID: NCVS1222
# Add of existing embedding ID: NCVS1223
# Add of existing embedding ID: NCVS1224
# Add of existing embedding ID: NCVS1225
# Add of existing embedding ID: NCVS1226
# Add of existing embedding ID: NCVS1227
# Add of existing embedding ID: NCVS1228
# Add of existing embedding ID: NCVS1229
# Add of existing embedding ID: NCVS1230
# ...
# Add of existing embedding ID: NCVS3441
# Add of existing embedding ID: NCVS3442
# Add of existing embedding ID: NCVS3443
# Add of existing embedding ID: NCVS3444
# Add of existing embedding ID: NCVS3445
# Add of existing embedding ID: NCVS3446
# Add of existing embedding ID: NCVS3447
# Add of existing embedding ID: NCVS3448
# Add of existing embedding ID: NCVS3449
# Add of existing embedding ID: NCVS3450
# Add of existing embedding ID: NCVS3451
# Add of existing embedding ID: NCVS3452
# Add of existing embedding ID: NCVS3453
# Add of existing embedding ID: NCVS3454
# Add of existing embedding ID: NCVS3455
# Add of existing embedding ID: NCVS3456
# Add of existing embedding ID: NCVS3457
# Add of existing embedding ID: NCVS3458
# Add of existing embedding ID: NCVS3459
# Add of existing embedding ID: NCVS3460
# Add of existing embedding ID: NCVS3461
# Add of existing embedding ID: NCVS3462
# Add of existing embedding ID: NCVS3463
# Add of existing embedding ID: NCVS3464
# Add of existing embedding ID: NCVS3465
# Add of existing embedding ID: NCVS3466
# Add of existing embedding ID: NCVS3467
# Add of existing embedding ID: NCVS3468
# Add of existing embedding ID: NCVS3469
# Add of existing embedding ID: NCVS3470
# Add of existing embedding ID: NCVS3471
# Add of existing embedding ID: NCVS3472
# Add of existing embedding ID: NCVS3473
# Add of existing embedding ID: NCVS3474
# Add of existing embedding ID: NCVS3475
# Add of existing embedding ID: NCVS3476
# Add of existing embedding ID: NCVS3477
# Add of existing embedding ID: NCVS3478
# Add of existing embedding ID: NCVS3479
# Add of existing embedding ID: NCVS3480
# Add of existing embedding ID: NCVS3481
# Add of existing embedding ID: NCVS3482
# Add of existing embedding ID: NCVS3483
# Add of existing embedding ID: NCVS3484
# Add of existing embedding ID: NCVS3485
# Add of existing embedding ID: NCVS3486
# Add of existing embedding ID: NCVS3487
# Add of existing embedding ID: NCVS3488
# Add of existing embedding ID: NCVS3489
# Add of existing embedding ID: NCVS3490
# Add of existing embedding ID: NCVS3491
# Add of existing embedding ID: NCVS3492
# Add of existing embedding ID: NCVS3493
# Add of existing embedding ID: NCVS3494
# Add of existing embedding ID: NCVS3495
# Add of existing embedding ID: NCVS3496
# Add of existing embedding ID: NCVS3497
# Add of existing embedding ID: NCVS3498
# Add of existing embedding ID: NCVS3499
# Add of existing embedding ID: NCVS3500
# Add of existing embedding ID: NCVS3501
# Add of existing embedding ID: NCVS3502
# Add of existing embedding ID: NCVS3503
# Add of existing embedding ID: NCVS3504
# Add of existing embedding ID: NCVS3505
# Add of existing embedding ID: NCVS3506
# Add of existing embedding ID: NCVS3507
# Add of existing embedding ID: NCVS3508
# Add of existing embedding ID: NCVS3509
# Add of existing embedding ID: NCVS3510
# Add of existing embedding ID: NCVS3511
# Add of existing embedding ID: NCVS3512
# Add of existing embedding ID: NCVS3513
# Add of existing embedding ID: NCVS3514
# Add of existing embedding ID: NCVS3515
# Add of existing embedding ID: NCVS3516
# Add of existing embedding ID: NCVS3517
# Add of existing embedding ID: NCVS3518
# Add of existing embedding ID: NCVS3519
# Add of existing embedding ID: NCVS3520
# Add of existing embedding ID: NCVS3521
# Add of existing embedding ID: NCVS3522
# Add of existing embedding ID: NCVS3523
# Add of existing embedding ID: NCVS3524
# Add of existing embedding ID: NCVS3525
# Add of existing embedding ID: NCVS3526
# Add of existing embedding ID: NCVS3527
# Add of existing embedding ID: NCVS3528
# Add of existing embedding ID: NCVS3529
# Add of existing embedding ID: NCVS3530
# Add of existing embedding ID: NCVS3531
# Add of existing embedding ID: NCVS3532
# Add of existing embedding ID: NCVS3533
# Add of existing embedding ID: NCVS3534
# Add of existing embedding ID: NCVS3535
# Add of existing embedding ID: NCVS3536
# Add of existing embedding ID: NCVS3537
# Add of existing embedding ID: NCVS3538
# Add of existing embedding ID: NCVS3539
# Add of existing embedding ID: NCVS3540
# Add of existing embedding ID: NCVS3541
# Add of existing embedding ID: NCVS3542
# Add of existing embedding ID: NCVS3543
# Add of existing embedding ID: NCVS3544
# Add of existing embedding ID: NCVS3545
# Add of existing embedding ID: NCVS3546
# Add of existing embedding ID: NCVS3547
# Add of existing embedding ID: NCVS3548
# Add of existing embedding ID: NCVS3549
# Add of existing embedding ID: NCVS3550
# Add of existing embedding ID: NCVS3551
# Add of existing embedding ID: NCVS3552
# Add of existing embedding ID: NCVS3553
# Add of existing embedding ID: NCVS3554
# Add of existing embedding ID: NCVS3555
# Add of existing embedding ID: NCVS3556
# Add of existing embedding ID: NCVS3557
# Add of existing embedding ID: NCVS3558
# Add of existing embedding ID: NCVS3559
# Add of existing embedding ID: NCVS3560
# Add of existing embedding ID: NCVS3561
# Add of existing embedding ID: NCVS3562
# Add of existing embedding ID: NCVS3563
# Add of existing embedding ID: NCVS3564
# Add of existing embedding ID: NCVS3565
# Add of existing embedding ID: NCVS3566
# Add of existing embedding ID: NCVS3567
# Add of existing embedding ID: NCVS3568
# Add of existing embedding ID: NCVS3569
# Add of existing embedding ID: NCVS3570
# Add of existing embedding ID: NCVS3571
# Add of existing embedding ID: NCVS3572
# Add of existing embedding ID: NCVS3573
# Add of existing embedding ID: NCVS3574
# Add of existing embedding ID: NCVS3575
# Add of existing embedding ID: NCVS3576
# Add of existing embedding ID: NCVS3577
# Add of existing embedding ID: NCVS3578
# Add of existing embedding ID: NCVS3579
# Add of existing embedding ID: NCVS3580
# Add of existing embedding ID: NCVS3581
# Add of existing embedding ID: NCVS3582
# Add of existing embedding ID: NCVS3583
# Add of existing embedding ID: NCVS3584
# Add of existing embedding ID: NCVS3585
# Add of existing embedding ID: NCVS3586
# Add of existing embedding ID: NCVS3587
# Add of existing embedding ID: NCVS3588
# Add of existing embedding ID: NCVS3589
# Add of existing embedding ID: NCVS3590
# Add of existing embedding ID: NCVS3591
# Add of existing embedding ID: NCVS3592
# Add of existing embedding ID: NCVS3593
# Add of existing embedding ID: NCVS3594
# Add of existing embedding ID: NCVS3595
# Add of existing embedding ID: NCVS3596
# Add of existing embedding ID: NCVS3597
# Add of existing embedding ID: NCVS3598
# Add of existing embedding ID: NCVS3599
# Add of existing embedding ID: NCVS3600
# Add of existing embedding ID: NCVS3601
# Add of existing embedding ID: NCVS3602
# Add of existing embedding ID: NCVS3603
# Add of existing embedding ID: NCVS3604
# Add of existing embedding ID: NCVS3605
# Add of existing embedding ID: NCVS3606
# Add of existing embedding ID: NCVS3607
# Add of existing embedding ID: NCVS3608
# Add of existing embedding ID: NCVS3609
# Add of existing embedding ID: NCVS3610
# Add of existing embedding ID: NCVS3611
# Add of existing embedding ID: NCVS3612
# Add of existing embedding ID: NCVS3613
# Add of existing embedding ID: NCVS3614
# Add of existing embedding ID: NCVS3615
# Add of existing embedding ID: NCVS3616
# Add of existing embedding ID: NCVS3617
# Add of existing embedding ID: NCVS3618
# Add of existing embedding ID: NCVS3619
# Add of existing embedding ID: NCVS3620
# Add of existing embedding ID: NCVS3621
# Add of existing embedding ID: NCVS3622
# Add of existing embedding ID: NCVS3623
# Add of existing embedding ID: NCVS3624
# Add of existing embedding ID: NCVS3625
# Add of existing embedding ID: NCVS3626
# Add of existing embedding ID: NCVS3627
# Add of existing embedding ID: NCVS3628
# Add of existing embedding ID: NCVS3629
# Add of existing embedding ID: NCVS3630
# Add of existing embedding ID: NCVS3631
# Add of existing embedding ID: NCVS3632
# Add of existing embedding ID: NCVS3633
# Add of existing embedding ID: NCVS3634
# Add of existing embedding ID: NCVS3635
# Add of existing embedding ID: NCVS3636
# Add of existing embedding ID: NCVS3637
# Add of existing embedding ID: NCVS3638
# Add of existing embedding ID: NCVS3639
# Add of existing embedding ID: NCVS3640
# Add of existing embedding ID: NCVS3641
# Add of existing embedding ID: NCVS3642
# Add of existing embedding ID: NCVS3643
# Add of existing embedding ID: NCVS3644
# Add of existing embedding ID: NCVS3645
# Add of existing embedding ID: NCVS3646
# Add of existing embedding ID: NCVS3647
# Add of existing embedding ID: NCVS3648
# Add of existing embedding ID: NCVS3649
# Add of existing embedding ID: NCVS3650
# Add of existing embedding ID: NCVS3651
# Add of existing embedding ID: NCVS3652
# Add of existing embedding ID: NCVS3653
# Add of existing embedding ID: NCVS3654
# Add of existing embedding ID: NCVS3655
# Add of existing embedding ID: NCVS3656
# Add of existing embedding ID: NCVS3657
# Add of existing embedding ID: NCVS3658
# Add of existing embedding ID: NCVS3659
# Add of existing embedding ID: NCVS3660
# Add of existing embedding ID: NCVS3661
# Add of existing embedding ID: NCVS3662
# Add of existing embedding ID: NCVS3663
# Add of existing embedding ID: NCVS3664
# Add of existing embedding ID: NCVS3665
# Add of existing embedding ID: NCVS3666
# Add of existing embedding ID: NCVS3667
# Add of existing embedding ID: NCVS3668
# Add of existing embedding ID: NCVS3669
# Add of existing embedding ID: NCVS3670
# Add of existing embedding ID: NCVS3671
# Add of existing embedding ID: NCVS3672
# Add of existing embedding ID: NCVS3673
# Add of existing embedding ID: NCVS3674
# Add of existing embedding ID: NCVS3675
# Add of existing embedding ID: NCVS3676
# Add of existing embedding ID: NCVS3677
# Add of existing embedding ID: NCVS3678
# Add of existing embedding ID: NCVS3679
# Add of existing embedding ID: NCVS3680
# Add of existing embedding ID: NCVS3681
# Add of existing embedding ID: NCVS3682
# Add of existing embedding ID: NCVS3683
# Add of existing embedding ID: NCVS3684
# Add of existing embedding ID: NCVS3685
# Add of existing embedding ID: NCVS3686
# Add of existing embedding ID: NCVS3687
# Add of existing embedding ID: NCVS3688
# Add of existing embedding ID: NCVS3689
# Add of existing embedding ID: NCVS3690
# Add of existing embedding ID: NCVS3691
# Add of existing embedding ID: NCVS3692
# Add of existing embedding ID: NCVS3693
# Add of existing embedding ID: NCVS3694
# Add of existing embedding ID: NCVS3695
# Add of existing embedding ID: NCVS3696
# Add of existing embedding ID: NCVS3697
# Add of existing embedding ID: NCVS3698
# Add of existing embedding ID: NCVS3699
# Add of existing embedding ID: NCVS3700
# Add of existing embedding ID: NCVS3701
# Add of existing embedding ID: NCVS3702
# Add of existing embedding ID: NCVS3703
# Add of existing embedding ID: NCVS3704
# Add of existing embedding ID: NCVS3705
# Add of existing embedding ID: NCVS3706
# Add of existing embedding ID: NCVS3707
# Add of existing embedding ID: NCVS3708
# Add of existing embedding ID: NCVS3709
# Add of existing embedding ID: NCVS3710
# Add of existing embedding ID: NCVS3711
# Add of existing embedding ID: NCVS3712
# Add of existing embedding ID: NCVS3713
# Add of existing embedding ID: NCVS3714
# Add of existing embedding ID: NCVS3715
# Add of existing embedding ID: NCVS3716
# Add of existing embedding ID: NCVS3717
# Add of existing embedding ID: NCVS3718
# Add of existing embedding ID: NCVS3719
# Add of existing embedding ID: NCVS3720
# Add of existing embedding ID: NCVS3721
# Add of existing embedding ID: NCVS3722
# Add of existing embedding ID: NCVS3723
# Add of existing embedding ID: NCVS3724
# Add of existing embedding ID: NCVS3725
# Add of existing embedding ID: NCVS3726
# Add of existing embedding ID: NCVS3727
# Add of existing embedding ID: NCVS3728
# Add of existing embedding ID: NCVS3729
# Add of existing embedding ID: NCVS3730
# Add of existing embedding ID: NCVS3731
# Add of existing embedding ID: NCVS3732
# Add of existing embedding ID: NCVS3733
# Add of existing embedding ID: NCVS3734
# Add of existing embedding ID: NCVS3735
# Add of existing embedding ID: NCVS3736
# Add of existing embedding ID: NCVS3737
# Add of existing embedding ID: NCVS3738
# Add of existing embedding ID: NCVS3739
# Add of existing embedding ID: NCVS3740
# Add of existing embedding ID: NCVS3741
# Add of existing embedding ID: NCVS3742
# Add of existing embedding ID: NCVS3743
# Add of existing embedding ID: NCVS3744
# Add of existing embedding ID: NCVS3745
# Add of existing embedding ID: NCVS3746
# Add of existing embedding ID: NCVS3747
# Add of existing embedding ID: NCVS3748
# Add of existing embedding ID: NCVS3749
# Add of existing embedding ID: NCVS3750
# Add of existing embedding ID: NCVS3751
# Add of existing embedding ID: NCVS3752
# Add of existing embedding ID: NCVS3753
# Add of existing embedding ID: NCVS3754
# Add of existing embedding ID: NCVS3755
# Add of existing embedding ID: NCVS3756
# Add of existing embedding ID: NCVS3757
# Add of existing embedding ID: NCVS3758
# Add of existing embedding ID: NCVS3759
# Add of existing embedding ID: NCVS3760
# Add of existing embedding ID: NCVS3761
# Add of existing embedding ID: NCVS3762
# Add of existing embedding ID: NCVS3763
# Add of existing embedding ID: NCVS3764
# Add of existing embedding ID: NCVS3765
# Add of existing embedding ID: NCVS3766
# Add of existing embedding ID: NCVS3767
# Add of existing embedding ID: NCVS3768
# Add of existing embedding ID: NCVS3769
# Add of existing embedding ID: NCVS3770
# Add of existing embedding ID: NCVS3771
# Add of existing embedding ID: NCVS3772
# Add of existing embedding ID: NCVS3773
# Add of existing embedding ID: NCVS3774
# Add of existing embedding ID: NCVS3775
# Add of existing embedding ID: NCVS3776
# Add of existing embedding ID: NCVS3777
# Add of existing embedding ID: NCVS3778
# Add of existing embedding ID: NCVS3779
# Add of existing embedding ID: NCVS3780
# Add of existing embedding ID: NCVS3781
# Add of existing embedding ID: NCVS3782
# Add of existing embedding ID: NCVS3783
# Add of existing embedding ID: NCVS3784
# Add of existing embedding ID: NCVS3785
# Add of existing embedding ID: NCVS3786
# Add of existing embedding ID: NCVS3787
# Add of existing embedding ID: NCVS3788
# Add of existing embedding ID: NCVS3789
# Add of existing embedding ID: NCVS3790
# Add of existing embedding ID: NCVS3791
# Add of existing embedding ID: NCVS3792
# Add of existing embedding ID: NCVS3793
# Add of existing embedding ID: NCVS3794
# Add of existing embedding ID: NCVS3795
# Add of existing embedding ID: NCVS3796
# Add of existing embedding ID: NCVS3797
# Add of existing embedding ID: NCVS3798
# Add of existing embedding ID: NCVS3799
# Add of existing embedding ID: NCVS3800
# Add of existing embedding ID: NCVS3801
# Add of existing embedding ID: NCVS3802
# Add of existing embedding ID: NCVS3803
# Add of existing embedding ID: NCVS3804
# Add of existing embedding ID: NCVS3805
# Add of existing embedding ID: NCVS3806
# Add of existing embedding ID: NCVS3807
# Add of existing embedding ID: NCVS3808
# Add of existing embedding ID: NCVS3809
# Add of existing embedding ID: NCVS3810
# Add of existing embedding ID: NCVS3811
# Add of existing embedding ID: NCVS3812
# Add of existing embedding ID: NCVS3813
# Add of existing embedding ID: NCVS3814
# Add of existing embedding ID: NCVS3815
# Add of existing embedding ID: NCVS3816
# Add of existing embedding ID: NCVS3817
# Add of existing embedding ID: NCVS3818
# Add of existing embedding ID: NCVS3819
# Add of existing embedding ID: NCVS3820
# Add of existing embedding ID: NCVS3821
# Add of existing embedding ID: NCVS3822
# Add of existing embedding ID: NCVS3823
# Add of existing embedding ID: NCVS3824
# Add of existing embedding ID: NCVS3825
# Add of existing embedding ID: NCVS3826
# Add of existing embedding ID: NCVS3827
# Add of existing embedding ID: NCVS3828
# Add of existing embedding ID: NCVS3829
# Add of existing embedding ID: NCVS3830
# Add of existing embedding ID: NCVS3831
# Add of existing embedding ID: NCVS3832
# Add of existing embedding ID: NCVS3833
# Question: How many categories does a lifeboat have?
#
# Answer: A lifeboat has two categories: Category A and Category B. Category A lifeboats are required to comply with international conventions, codes, and amendments related to lifeboats, while Category B lifeboats are open boats constructed with rigid sides and designed to have ample stability and sufficient freeboard when loaded with equipment and the specified number of persons according to its capacity. These categories have specific construction and capacity requirements outlined for each type of lifeboat.
#
# Sources:
# - CHAPTER-4_LIFE_SAVING_APPLIANCES_v.4.4_1708919237619_0.pdf, page: 7

# %%
question = "Can you elaborate to me what are the differences of each life jacket categories?" 
print("Question: {}\n\nAnswer: {}".format(question, 
                                           generate_openai_response(question)))
# Out:
# Question: Can you elaborate to me what are the differences of each life jacket categories?
#
# Answer: The differences between each life jacket category are outlined in the context provided. Here is a breakdown of the key distinctions:
#
# 1. Category A Life Jackets:
#    - These life jackets are required to have buoyancy that is not decreased by more than 5 percent after being immersed in fresh water for 24 hours.
#    - They should enable the wearer to swim short distances and climb up a lifeboat.
#    - Each life jacket must be equipped with a whistle attached by a line and a self-illuminating light when immersed in water.
#
# 2. Category B Life Jackets:
#    - Category B life jackets must comply with specific requirements, including having a whistle firmly attached to each life jacket.
#    - They should be marked with clear instructions for donning and must be suitable for all body weight ranges.
#
# 3. Category C Life Jackets:
#    - Category C life jackets, excluding those relying on inflation for buoyancy, are intended for specific uses defined by the Authority.
#    - They must be clearly marked 'LIFE JACKET' in indelible lettering not less than 25 mm high.
#    - These life jackets should have reflective material, be visible from most directions in the water, and be white in color.
#
# Each category of life jacket has its own set of requirements and specifications to ensure the safety and effectiveness of the life-saving appliance based on different usage scenarios and needs.
#
# Sources:
# - CHAPTER-4_LIFE_SAVING_APPLIANCES_v.4.4_1708919237619_0.pdf, page: 25
# - CHAPTER-4_LIFE_SAVING_APPLIANCES_v.4.4_1708919237619_0.pdf, page: 26
# - CHAPTER-4_LIFE_SAVING_APPLIANCES_v.4.4_1708919237619_0.pdf, page: 28

# %%
question = "Explain in detail about a vessel's minimum anchor mass."
print("Question: {}\n\nAnswer: {}".format(question, 
                                           generate_openai_response(question)))
# Out:
# Question: Explain in detail about a vessel's minimum anchor mass.
#
# Answer: The minimum anchor mass for a vessel is determined based on its measured length and operating profile. For vessels more than 24 meters in length, the minimum mass per anchor is calculated using the equipment number specified in the regulations. On the other hand, for vessels up to 24 meters in length, the minimum mass per anchor is determined by either applying values from specific tables for vessels up to 24 meters or calculating the mass from the equipment number as per the regulations.
#
# The formula used to calculate the mass of a single anchor is MA = MT * fV * fA, where MA is the mass of a single anchor in kilograms, MT is the tabular mass of the anchor from specific tables, fV is the speed factor (1 if maximum speed is less than Vm, 0.75 if maximum speed is Vm or more), and fA varies depending on the type of anchor used (1 for standard anchors, 0.7 for high holding power anchors, and 0.55 for extra high holding power anchors).
#
# The number of anchors required to be carried by a vessel depends on its operating profile, which considers factors like the distance the vessel will travel from a safe haven and the type of sea conditions it will encounter. The operating profile helps assess the risk to the vessel in case of environmental factors or onboard issues that may require temporary anchoring for safety.
#
# In cases where the vessel parameters fall between the values shown in the tables, the anchor mass should be calculated by interpolation. If an anchor of the calculated mass is not available, the next higher size anchor should be selected to ensure adequate anchoring capability for the vessel.
#
# Overall, the minimum anchor mass for a vessel is a critical factor in ensuring the safety and stability of the vessel during anchoring operations, and it is determined based on the vessel's size, operating profile, and specific technical requirements outlined in the regulations.
#
# Sources:
# - CHAPTER-2_CONSTRUCTION_v._4.4_1708919219897_0.pdf, page: 122
# - CHAPTER-2_CONSTRUCTION_v._4.4_1708919219897_0.pdf, page: 123
# - CHAPTER-2_CONSTRUCTION_v._4.4_1708919219897_0.pdf, page: 125
